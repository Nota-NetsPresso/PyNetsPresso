# %% [markdown]
# <div align="center">
#   <a href="https://netspresso.ai/?utm_source=colab_bp&utm_medium=banner_py&utm_campaign=np_renew" target="_blank">
#   <img src="https://netspresso-docs-imgs.s3.ap-northeast-2.amazonaws.com/imgs/banner/netspresso_qualcomm_banne.png"/>
# </div>

# %% [markdown]
# # Install NetsPresso

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# - Python `3.8` | `3.9` | `3.10`
# - PyTorch `1.13.0` (recommended) (compatible with: `1.11.x` - `1.13.x`)
# - TensorFlow `2.8.0` (recommended) (compatible with: `2.3.x` - `2.8.x`)
#
# To use **editable mode** or **docker**, see [INSTALLATION.md](https://github.com/Nota-NetsPresso/PyNetsPresso/blob/develop/INSTALLATION.md).

# %% [markdown]
# ## Install with PyPI

# %%
# !python --version

# %%
# !pip install netspresso

# %% [markdown]
# # Login NetsPresso

# %%
from netspresso import NetsPresso, NPQAI


EMAIL = "YOUR_EMAIL"
PASSWORD = "YOUR_PASSWORD"
QAI_HUB_API_TOKEN = "YOUR_QAI_HUB_API_TOKEN"

netspresso = NetsPresso(email=EMAIL, password=PASSWORD)
np_qai = NPQAI(api_token=QAI_HUB_API_TOKEN)
# Out:
# 2025-02-13 04:07:41.669 | INFO     | netspresso.clients.config:_print_host_and_port:41 - Host: https://v2-prod.netspresso.ai, Port: 43001
# 2025-02-13 04:07:46.184 | INFO     | netspresso.clients.auth.v2.client:login:35 - Login successfully
# 2025-02-13 04:07:46.463 | INFO     | netspresso.clients.auth.v2.client:get_user_info:44 - Successfully got user information
# 2025-02-13 04:07:46.987 | INFO     | netspresso.netspresso:__init__:160 - CompletedProcess(args=['qai-hub', 'configure', '--api_token', '10ddcf0c0d02113d455ebe1e527f98db5b458593'], returncode=0, stdout='qai-hub configuration saved to /root/.qai_hub/client.ini\n==================== /root/.qai_hub/client.ini ====================\n[api]\napi_token = 10ddcf0c0d02113d455ebe1e527f98db5b458593\napi_url = https://app.aihub.qualcomm.com\nweb_url = https://app.aihub.qualcomm.com\nverbose = True\n\n\n', stderr='/opt/conda/lib/python3.10/site-packages/qai_hub/_cli.py:358: UserWarning: Overwriting configuration: /root/.qai_hub/client.ini (previous configuration saved to /root/.qai_hub/client.ini.bak)\n  warnings.warn(\n')

# %% [markdown]
# # 1. Train the model(using YOLOX)

# %% [markdown]
# ## 1-1. Download Dataset

# %%
# !wget https://netspresso-github.s3.ap-northeast-2.amazonaws.com/traffic-sign.zip
# !unzip traffic-sign.zip

# %% [markdown]
# ## 1-2. Train the model

# %%
from netspresso.enums import Task
from netspresso.trainer.augmentations import Resize, ToTensor, Normalize
from netspresso.trainer.optimizers import AdamW
from netspresso.trainer.schedulers import CosineAnnealingWarmRestartsWithCustomWarmUp

IMG_SIZE=512

# 1. Declare trainer
trainer = netspresso.trainer(task=Task.OBJECT_DETECTION)
trainer.set_dataset_config(
    name="traffic_sign_config_example",
    root_path="./traffic-sign",
    train_image="images/train",
    train_label="labels/train",
    valid_image="images/valid",
    valid_label="labels/valid",
    id_mapping=["prohibitory", "danger", "mandatory", "other"],
)
trainer.set_model_config(model_name="YOLOX-S", img_size=IMG_SIZE)
trainer.set_augmentation_config(
    train_transforms=[Resize(), ToTensor(), Normalize()],
    inference_transforms=[Resize(), ToTensor(), Normalize()],
)
trainer.set_training_config(
    epochs=45,
    batch_size=64,
    optimizer=AdamW(lr=6e-3),
    scheduler=CosineAnnealingWarmRestartsWithCustomWarmUp(warmup_epochs=10),
)
project_name = "qai-hub-yolox-s"
trained_result = trainer.train(gpus="0, 1", project_name=project_name)
# Out:
# 2025-02-13 04:08:59.544 | INFO     | netspresso.utils.file:create_unique_folder:90 - The folder has been created. Local Path: outputs/qai-hub-yolox-s (1)
# 2025-02-13 04:08:59.547 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/metadata.json
# /opt/conda/lib/python3.10/site-packages/torch/distributed/launch.py:180: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   warnings.warn(
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# 2025-02-13 04:09:03.387 | INFO     | netspresso_trainer.trainer_common:train_common:50 - Task: detection | Model: yolox_s | Training with torch.fx model? False
# 2025-02-13 04:09:03.388 | INFO     | netspresso_trainer.trainer_common:train_common:51 - Result will be saved at outputs/qai-hub-yolox-s (1)/version_0
# 2025-02-13 04:09:03.389 | INFO     | netspresso_trainer.dataloaders.builder:build_dataset:97 - ----------------------------------------
# 2025-02-13 04:09:03.389 | INFO     | netspresso_trainer.dataloaders.builder:build_dataset:98 - Loading data...
# 2025-02-13 04:09:03.390 | WARNING  | netspresso_trainer.dataloaders.builder:dataset_path_check:41 - For training, test split of dataset is not needed. This field will be ignored.
# 2025-02-13 04:09:03.429 | INFO     | netspresso_trainer.dataloaders.builder:loaded_dataset_check:72 - Summary | Dataset: <traffic_sign_config_example> (with local format)
# 2025-02-13 04:09:03.430 | INFO     | netspresso_trainer.dataloaders.builder:loaded_dataset_check:73 - Summary | Training dataset: 630 sample(s)
# 2025-02-13 04:09:03.430 | INFO     | netspresso_trainer.dataloaders.builder:loaded_dataset_check:75 - Summary | Validation dataset: 111 sample(s)
# 2025-02-13 04:09:04.823 | INFO     | netspresso_trainer.models.utils:load_from_checkpoint:216 - Pretrained model for yolox_s is loaded from: /root/.cache/netspresso_trainer/yolox_s/yolox_s_coco.safetensors
# 2025-02-13 04:09:04.836 | INFO     | netspresso_trainer.models.utils:load_from_checkpoint:220 - ----------------------------------------
# 2025-02-13 04:09:04.836 | INFO     | netspresso_trainer.models.utils:load_from_checkpoint:221 - Head weights are not loaded because model.checkpoint.load_head is set to False
#   0%|          | 0/4 [00:00<?, ?it/s]2025-02-13 04:09:06.998 | INFO     | netspresso_trainer.pipelines.train:train:128 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s][W reducer.cpp:1298] Warning: find_unused_parameters=True was specified in DDP constructor, but did not find any unused parameters in the forward pass. This flag results in an extra traversal of the autograd graph every iteration,  which can adversely affect performance. If your model indeed never has any unused parameters in the forward pass, consider turning this flag off. Note that this warning may be a false positive if your model has flow control causing later iterations to have unused parameters. (function operator())
# [W reducer.cpp:1298] Warning: find_unused_parameters=True was specified in DDP constructor, but did not find any unused parameters in the forward pass. This flag results in an extra traversal of the autograd graph every iteration,  which can adversely affect performance. If your model indeed never has any unused parameters in the forward pass, consider turning this flag off. Note that this warning may be a false positive if your model has flow control causing later iterations to have unused parameters. (function operator())
# 2025-02-13 04:09:17.737 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 1 / 45
# 2025-02-13 04:09:17.738 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0006090
# 2025-02-13 04:09:17.738 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 10.7369945
# 2025-02-13 04:09:17.738 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 41.1370668
# 2025-02-13 04:09:17.738 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.0247667729561328), ('map75', 0.005622018784551708), ('map50_95', 0.01043088493307721)]
# 2025-02-13 04:09:23.302 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - validation loss: 47.4143193
# 2025-02-13 04:09:23.302 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - validation metric: [('map50', 0.0), ('map75', 0.0), ('map50_95', 0.0)]
# 2025-02-13 04:09:23.325 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:09:24.690 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]2025-02-13 04:09:31.774 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 2 / 45
# 2025-02-13 04:09:31.775 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0012080
# 2025-02-13 04:09:31.775 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.0820959
# 2025-02-13 04:09:31.775 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 22.4689026
# 2025-02-13 04:09:31.775 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.05135617476428988), ('map75', 0.04426717521824032), ('map50_95', 0.03275481655793646)]
# 2025-02-13 04:09:31.777 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:09:31.777 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]2025-02-13 04:09:39.104 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 3 / 45
# 2025-02-13 04:09:39.105 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0018070
# 2025-02-13 04:09:39.105 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.3254099
# 2025-02-13 04:09:39.106 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 17.8252084
# 2025-02-13 04:09:39.106 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.029706800873805356), ('map75', 0.005185720694350115), ('map50_95', 0.01056193961363989)]
# 2025-02-13 04:09:39.108 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:09:39.108 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]2025-02-13 04:09:46.281 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 4 / 45
# 2025-02-13 04:09:46.283 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0024060
# 2025-02-13 04:09:46.283 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.1720073
# 2025-02-13 04:09:46.284 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 14.6742280
# 2025-02-13 04:09:46.284 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.122197435411317), ('map75', 0.004602263544205314), ('map50_95', 0.0327979651878048)]
# 2025-02-13 04:09:46.285 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:09:46.286 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]2025-02-13 04:09:53.432 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 5 / 45
# 2025-02-13 04:09:53.433 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0030050
# 2025-02-13 04:09:53.433 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.1454704
# 2025-02-13 04:09:53.433 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 12.4905355
# 2025-02-13 04:09:53.434 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.1119242552299069), ('map75', 0.005155185465749576), ('map50_95', 0.027745189203504002)]
# 2025-02-13 04:09:53.436 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:09:53.436 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]2025-02-13 04:10:00.689 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 6 / 45
# 2025-02-13 04:10:00.690 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0036040
# 2025-02-13 04:10:00.691 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.2520583
# 2025-02-13 04:10:00.691 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 11.6467490
# 2025-02-13 04:10:00.691 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.14593748064497059), ('map75', 0.005468339397492152), ('map50_95', 0.03166723264115415)]
# 2025-02-13 04:10:00.693 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:10:00.694 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]2025-02-13 04:10:07.764 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 7 / 45
# 2025-02-13 04:10:07.766 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0042030
# 2025-02-13 04:10:07.766 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.0697238
# 2025-02-13 04:10:07.766 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 11.3523571
# 2025-02-13 04:10:07.767 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.1546864352479797), ('map75', 0.005219404768006534), ('map50_95', 0.0373521761196259)]
# 2025-02-13 04:10:07.768 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:10:07.769 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]2025-02-13 04:10:14.883 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 8 / 45
# 2025-02-13 04:10:14.885 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0048020
# 2025-02-13 04:10:14.885 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.1137905
# 2025-02-13 04:10:14.885 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 9.7805588
# 2025-02-13 04:10:14.885 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.2317410563374892), ('map75', 0.013034197929524934), ('map50_95', 0.06396241109941228)]
# 2025-02-13 04:10:14.888 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:10:14.888 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]2025-02-13 04:10:22.191 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 9 / 45
# 2025-02-13 04:10:22.192 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0054010
# 2025-02-13 04:10:22.192 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.3016245
# 2025-02-13 04:10:22.193 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 9.1549187
# 2025-02-13 04:10:22.193 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.23209962409362994), ('map75', 0.017199733915344892), ('map50_95', 0.06653544409057902)]
# 2025-02-13 04:10:22.194 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:10:22.195 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]2025-02-13 04:10:29.352 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 10 / 45
# 2025-02-13 04:10:29.353 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0060000
# 2025-02-13 04:10:29.353 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.1559279
# 2025-02-13 04:10:29.353 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 7.8651938
# 2025-02-13 04:10:29.354 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.46707404475110004), ('map75', 0.08697376829776365), ('map50_95', 0.16707529967907658)]
# 2025-02-13 04:10:29.356 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:10:29.356 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
# 2025-02-13 04:10:38.741 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 11 / 45
# 2025-02-13 04:10:38.742 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0060000
# 2025-02-13 04:10:38.742 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 9.3839531
# 2025-02-13 04:10:38.742 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 7.0038933
# 2025-02-13 04:10:38.743 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.583890325085185), ('map75', 0.0763463892178635), ('map50_95', 0.21052503240567272)]
# 2025-02-13 04:10:44.159 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - validation loss: 432.7568316
# 2025-02-13 04:10:44.160 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - validation metric: [('map50', 0.0), ('map75', 0.0), ('map50_95', 0.0)]
# 2025-02-13 04:10:44.183 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:10:45.541 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 04:10:52.639 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 12 / 45
# 2025-02-13 04:10:52.640 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0058532
# 2025-02-13 04:10:52.640 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.0962088
# 2025-02-13 04:10:52.640 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 6.2301958
# 2025-02-13 04:10:52.641 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.6033284337778978), ('map75', 0.2101761349897945), ('map50_95', 0.28715061804333997)]
# 2025-02-13 04:10:52.644 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:10:52.644 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]2025-02-13 04:10:59.785 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 13 / 45
# 2025-02-13 04:10:59.786 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0054271
# 2025-02-13 04:10:59.786 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.1394196
# 2025-02-13 04:10:59.786 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 7.4673042
# 2025-02-13 04:10:59.786 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.3562773525446782), ('map75', 0.04891543338743744), ('map50_95', 0.1286934111140556)]
# 2025-02-13 04:10:59.789 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:10:59.789 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 04:11:06.903 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 14 / 45
# 2025-02-13 04:11:06.904 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0047636
# 2025-02-13 04:11:06.904 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.1126409
# 2025-02-13 04:11:06.905 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 5.9214772
# 2025-02-13 04:11:06.905 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.6486978247294578), ('map75', 0.1443307024727108), ('map50_95', 0.2817300550191245)]
# 2025-02-13 04:11:06.908 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:11:06.908 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 04:11:14.443 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 15 / 45
# 2025-02-13 04:11:14.445 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0039274
# 2025-02-13 04:11:14.445 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.5342302
# 2025-02-13 04:11:14.445 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 5.2432553
# 2025-02-13 04:11:14.446 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.803210703369673), ('map75', 0.2850427240462521), ('map50_95', 0.372469058501657)]
# 2025-02-13 04:11:14.448 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:11:14.448 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 04:11:21.576 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 16 / 45
# 2025-02-13 04:11:21.577 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0030005
# 2025-02-13 04:11:21.578 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.1264486
# 2025-02-13 04:11:21.578 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 4.5448602
# 2025-02-13 04:11:21.578 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.8585758219375956), ('map75', 0.36698694025177914), ('map50_95', 0.4373843834849135)]
# 2025-02-13 04:11:21.581 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:11:21.581 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 04:11:28.851 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 17 / 45
# 2025-02-13 04:11:28.852 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0020736
# 2025-02-13 04:11:28.852 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.2685754
# 2025-02-13 04:11:28.852 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 3.9262840
# 2025-02-13 04:11:28.853 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.9025764447684759), ('map75', 0.642018585290535), ('map50_95', 0.5565890780296142)]
# 2025-02-13 04:11:28.855 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:11:28.856 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 04:11:36.219 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 18 / 45
# 2025-02-13 04:11:36.221 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0012374
# 2025-02-13 04:11:36.221 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.3619795
# 2025-02-13 04:11:36.221 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 3.6696330
# 2025-02-13 04:11:36.221 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.9159742563669179), ('map75', 0.6973828308618983), ('map50_95', 0.5788839942881638)]
# 2025-02-13 04:11:36.224 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:11:36.225 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 04:11:43.454 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 19 / 45
# 2025-02-13 04:11:43.455 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0005739
# 2025-02-13 04:11:43.455 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.2276082
# 2025-02-13 04:11:43.456 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 3.2888618
# 2025-02-13 04:11:43.456 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.9400269750032024), ('map75', 0.7908103414374527), ('map50_95', 0.6584373270925274)]
# 2025-02-13 04:11:43.458 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:11:43.459 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 04:11:50.604 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 20 / 45
# 2025-02-13 04:11:50.606 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0001478
# 2025-02-13 04:11:50.606 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.1448324
# 2025-02-13 04:11:50.606 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 3.0930950
# 2025-02-13 04:11:50.607 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.94522076426463), ('map75', 0.8367980050958744), ('map50_95', 0.6788382689066367)]
# 2025-02-13 04:11:50.608 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:11:50.609 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
# 2025-02-13 04:12:00.196 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 21 / 45
# 2025-02-13 04:12:00.197 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0060000
# 2025-02-13 04:12:00.197 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 9.5862124
# 2025-02-13 04:12:00.197 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 8.0280606
# 2025-02-13 04:12:00.198 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.28794955530028876), ('map75', 0.1336409675197706), ('map50_95', 0.1411702547847608)]
# 2025-02-13 04:12:05.481 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - validation loss: 14.3286636
# 2025-02-13 04:12:05.482 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - validation metric: [('map50', 0.1643007858769672), ('map75', 0.018032880346977188), ('map50_95', 0.04867441445784428)]
# 2025-02-13 04:12:05.490 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:12:06.687 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 04:12:13.769 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 22 / 45
# 2025-02-13 04:12:13.770 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0058532
# 2025-02-13 04:12:13.770 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.0811658
# 2025-02-13 04:12:13.771 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 7.4254602
# 2025-02-13 04:12:13.771 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.4303377436744395), ('map75', 0.0856882177495765), ('map50_95', 0.15584951907847663)]
# 2025-02-13 04:12:13.776 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:12:13.776 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 04:12:20.940 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 23 / 45
# 2025-02-13 04:12:20.941 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0054271
# 2025-02-13 04:12:20.941 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.1628234
# 2025-02-13 04:12:20.942 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 6.2986213
# 2025-02-13 04:12:20.942 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.5456765850275974), ('map75', 0.13987761705109533), ('map50_95', 0.2264419092079833)]
# 2025-02-13 04:12:20.945 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:12:20.945 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 04:12:28.216 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 24 / 45
# 2025-02-13 04:12:28.217 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0047636
# 2025-02-13 04:12:28.217 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.2694077
# 2025-02-13 04:12:28.217 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 5.8227578
# 2025-02-13 04:12:28.218 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.6262592796860404), ('map75', 0.13810877315315626), ('map50_95', 0.2490880011711616)]
# 2025-02-13 04:12:28.221 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:12:28.221 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 04:12:35.466 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 25 / 45
# 2025-02-13 04:12:35.468 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0039274
# 2025-02-13 04:12:35.468 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.2443986
# 2025-02-13 04:12:35.468 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 4.7335225
# 2025-02-13 04:12:35.469 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.7643658455958391), ('map75', 0.3346707136372949), ('map50_95', 0.39281205547637016)]
# 2025-02-13 04:12:35.472 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:12:35.472 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 04:12:42.494 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 26 / 45
# 2025-02-13 04:12:42.495 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0030005
# 2025-02-13 04:12:42.496 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.0213153
# 2025-02-13 04:12:42.496 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 4.5073546
# 2025-02-13 04:12:42.496 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.8435552559431869), ('map75', 0.34596944900970794), ('map50_95', 0.4201936911826971)]
# 2025-02-13 04:12:42.499 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:12:42.499 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 04:12:49.651 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 27 / 45
# 2025-02-13 04:12:49.652 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0020736
# 2025-02-13 04:12:49.652 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.1503406
# 2025-02-13 04:12:49.652 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 4.1981093
# 2025-02-13 04:12:49.652 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.9028310944529687), ('map75', 0.4290158354578804), ('map50_95', 0.4744423313459592)]
# 2025-02-13 04:12:49.656 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:12:49.656 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 04:12:56.681 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 28 / 45
# 2025-02-13 04:12:56.682 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0012374
# 2025-02-13 04:12:56.683 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.0241022
# 2025-02-13 04:12:56.683 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 3.5443505
# 2025-02-13 04:12:56.683 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.9321209823531771), ('map75', 0.7019342876715026), ('map50_95', 0.5972344493589148)]
# 2025-02-13 04:12:56.686 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:12:56.687 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 04:13:03.718 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 29 / 45
# 2025-02-13 04:13:03.720 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0005739
# 2025-02-13 04:13:03.720 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.0306020
# 2025-02-13 04:13:03.720 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 3.2606650
# 2025-02-13 04:13:03.720 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.9461211665627268), ('map75', 0.7613433340268085), ('map50_95', 0.6253951990562123)]
# 2025-02-13 04:13:03.724 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:13:03.724 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 04:13:10.956 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 30 / 45
# 2025-02-13 04:13:10.957 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0001478
# 2025-02-13 04:13:10.958 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.2309794
# 2025-02-13 04:13:10.958 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 2.9498017
# 2025-02-13 04:13:10.958 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.955132764702425), ('map75', 0.8768784705650636), ('map50_95', 0.6974042942139779)]
# 2025-02-13 04:13:10.961 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:13:10.961 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
# 2025-02-13 04:13:20.485 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 31 / 45
# 2025-02-13 04:13:20.486 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0060000
# 2025-02-13 04:13:20.486 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 9.5227153
# 2025-02-13 04:13:20.486 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 7.2206829
# 2025-02-13 04:13:20.487 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.4203627808814783), ('map75', 0.1542554006671846), ('map50_95', 0.1813563014905482)]
# 2025-02-13 04:13:25.855 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - validation loss: 10.3304267
# 2025-02-13 04:13:25.855 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - validation metric: [('map50', 0.22533269509994538), ('map75', 0.028313789566184022), ('map50_95', 0.07842174263209482)]
# 2025-02-13 04:13:25.875 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:13:27.190 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 04:13:34.366 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 32 / 45
# 2025-02-13 04:13:34.367 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0059345
# 2025-02-13 04:13:34.368 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.1751008
# 2025-02-13 04:13:34.368 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 6.8225316
# 2025-02-13 04:13:34.368 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.40731400707188087), ('map75', 0.09719314090407527), ('map50_95', 0.17218906656824184)]
# 2025-02-13 04:13:34.371 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:13:34.371 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 04:13:41.460 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 33 / 45
# 2025-02-13 04:13:41.461 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0057407
# 2025-02-13 04:13:41.461 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.0878778
# 2025-02-13 04:13:41.461 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 5.1885731
# 2025-02-13 04:13:41.462 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.7683581816241895), ('map75', 0.30405300156414117), ('map50_95', 0.3702464663565226)]
# 2025-02-13 04:13:41.465 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:13:41.465 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 04:13:48.434 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 34 / 45
# 2025-02-13 04:13:48.435 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0054271
# 2025-02-13 04:13:48.435 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 6.9674277
# 2025-02-13 04:13:48.435 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 4.9038631
# 2025-02-13 04:13:48.436 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.6892210716986276), ('map75', 0.27308097095266676), ('map50_95', 0.3257961841888809)]
# 2025-02-13 04:13:48.439 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:13:48.439 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 04:13:55.464 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 35 / 45
# 2025-02-13 04:13:55.466 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0050076
# 2025-02-13 04:13:55.466 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.0238531
# 2025-02-13 04:13:55.466 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 4.2387931
# 2025-02-13 04:13:55.466 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.8742106422403133), ('map75', 0.49954362402687436), ('map50_95', 0.49343710148724806)]
# 2025-02-13 04:13:55.470 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:13:55.471 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 04:14:02.382 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 36 / 45
# 2025-02-13 04:14:02.384 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0045002
# 2025-02-13 04:14:02.384 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 6.9112391
# 2025-02-13 04:14:02.384 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 3.9280874
# 2025-02-13 04:14:02.384 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.9546980393873117), ('map75', 0.4432715986748802), ('map50_95', 0.5060630719244069)]
# 2025-02-13 04:14:02.388 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:14:02.388 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 04:14:09.366 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 37 / 45
# 2025-02-13 04:14:09.368 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0039274
# 2025-02-13 04:14:09.368 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 6.9771988
# 2025-02-13 04:14:09.368 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 3.2414445
# 2025-02-13 04:14:09.368 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.9644119309476629), ('map75', 0.6900280516687908), ('map50_95', 0.601078827454372)]
# 2025-02-13 04:14:09.372 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:14:09.372 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 04:14:16.388 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 38 / 45
# 2025-02-13 04:14:16.390 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0033140
# 2025-02-13 04:14:16.390 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.0145695
# 2025-02-13 04:14:16.390 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 3.1044782
# 2025-02-13 04:14:16.390 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.978075677901404), ('map75', 0.7702621991508627), ('map50_95', 0.6437150221682357)]
# 2025-02-13 04:14:16.394 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:14:16.394 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 04:14:23.433 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 39 / 45
# 2025-02-13 04:14:23.435 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0026870
# 2025-02-13 04:14:23.435 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.0379727
# 2025-02-13 04:14:23.436 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 3.6202146
# 2025-02-13 04:14:23.436 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.9607413490553787), ('map75', 0.4183503913474409), ('map50_95', 0.49519706148050024)]
# 2025-02-13 04:14:23.439 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:14:23.439 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 04:14:30.741 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 40 / 45
# 2025-02-13 04:14:30.743 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0020736
# 2025-02-13 04:14:30.743 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.3014333
# 2025-02-13 04:14:30.743 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 3.2087218
# 2025-02-13 04:14:30.743 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.978784168793602), ('map75', 0.6165350531372824), ('map50_95', 0.5805880512748821)]
# 2025-02-13 04:14:30.747 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:14:30.747 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
# 2025-02-13 04:14:40.126 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 41 / 45
# 2025-02-13 04:14:40.128 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0015008
# 2025-02-13 04:14:40.129 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 9.3755522
# 2025-02-13 04:14:40.129 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 2.9228749
# 2025-02-13 04:14:40.130 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.9798254440400498), ('map75', 0.7795070152078258), ('map50_95', 0.6428382543568031)]
# 2025-02-13 04:14:45.702 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - validation loss: 4.5954770
# 2025-02-13 04:14:45.703 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - validation metric: [('map50', 0.8173507137745277), ('map75', 0.4321724460228745), ('map50_95', 0.44658304306737173)]
# 2025-02-13 04:14:45.724 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:14:47.072 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 04:14:54.446 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 42 / 45
# 2025-02-13 04:14:54.447 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0009934
# 2025-02-13 04:14:54.447 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.3717401
# 2025-02-13 04:14:54.448 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 2.7422929
# 2025-02-13 04:14:54.448 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.981752724255389), ('map75', 0.8755928695443732), ('map50_95', 0.6794562799865334)]
# 2025-02-13 04:14:54.452 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:14:54.452 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 04:15:01.836 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 43 / 45
# 2025-02-13 04:15:01.838 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0005739
# 2025-02-13 04:15:01.838 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.3829079
# 2025-02-13 04:15:01.838 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 2.2716725
# 2025-02-13 04:15:01.838 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.9803902706592298), ('map75', 0.9283475028679531), ('map50_95', 0.7802677038064497)]
# 2025-02-13 04:15:01.842 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:15:01.843 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 04:15:08.911 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 44 / 45
# 2025-02-13 04:15:08.913 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0002603
# 2025-02-13 04:15:08.914 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.0674138
# 2025-02-13 04:15:08.914 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 2.1389208
# 2025-02-13 04:15:08.914 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.9828804162160325), ('map75', 0.948930004339585), ('map50_95', 0.7828665586807865)]
# 2025-02-13 04:15:08.923 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:15:08.923 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
# 2025-02-13 04:15:18.125 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 45 / 45
# 2025-02-13 04:15:18.127 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0000665
# 2025-02-13 04:15:18.128 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 9.2006731
# 2025-02-13 04:15:18.128 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 2.0580585
# 2025-02-13 04:15:18.129 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.9830128297165497), ('map75', 0.9517170116200399), ('map50_95', 0.8104060893563423)]
# 2025-02-13 04:15:23.540 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - validation loss: 3.6958814
# 2025-02-13 04:15:23.541 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - validation metric: [('map50', 0.8465276379312395), ('map75', 0.6926784355651322), ('map50_95', 0.5907023555808765)]
# 2025-02-13 04:15:23.557 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:15:24.943 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
# 2025-02-13 04:15:24.944 | INFO     | netspresso_trainer.pipelines.train:train:166 - Total time: 377.94 s
# 2025-02-13 04:15:25.149 | INFO     | netspresso_trainer.pipelines.train:save_best:295 - Best model saved at outputs/qai-hub-yolox-s (1)/version_0/detection_yolox_s_best.safetensors
# /opt/conda/lib/python3.10/site-packages/torch/onnx/_internal/jit_utils.py:258: UserWarning: The shape inference of prim::Constant type is missing, so it may result in wrong shape inference for the exported graph. Please consider adding it in symbolic function. (Triggered internally at ../torch/csrc/jit/passes/onnx/shape_type_inference.cpp:1884.)
#   _C._jit_pass_onnx_node_shape_type_inference(node, params_dict, opset_version)
# /opt/conda/lib/python3.10/site-packages/torch/onnx/utils.py:687: UserWarning: The shape inference of prim::Constant type is missing, so it may result in wrong shape inference for the exported graph. Please consider adding it in symbolic function. (Triggered internally at ../torch/csrc/jit/passes/onnx/shape_type_inference.cpp:1884.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# /opt/conda/lib/python3.10/site-packages/torch/onnx/utils.py:1178: UserWarning: The shape inference of prim::Constant type is missing, so it may result in wrong shape inference for the exported graph. Please consider adding it in symbolic function. (Triggered internally at ../torch/csrc/jit/passes/onnx/shape_type_inference.cpp:1884.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# 2025-02-13 04:15:26.770 | INFO     | netspresso_trainer.pipelines.train:save_best:299 - ONNX model converting and saved at outputs/qai-hub-yolox-s (1)/version_0/detection_yolox_s_best.onnx
# 2025-02-13 04:15:26.943 | INFO     | netspresso_trainer.pipelines.train:save_best:302 - PyTorch FX model tracing and saved at outputs/qai-hub-yolox-s (1)/version_0/detection_yolox_s_best.pt
# 2025-02-13 04:15:27.286 | INFO     | netspresso_trainer.pipelines.train:save_summary:322 - [Model stats] | Sample input: (1, 3, 512, 512) | Params: 8.94M | FLOPs: 17.05G
# 2025-02-13 04:15:27.289 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/qai-hub-yolox-s (1)/version_0/training_summary.json
# 2025-02-13 04:15:31.630 | INFO     | netspresso.clients.launcher.v2.converter:read_framework_options:175 - Request Convert options
# 2025-02-13 04:15:31.835 | INFO     | netspresso.clients.launcher.v2.converter:read_framework_options:180 - Request Convert Task Options by model_framework: ResponseConvertFrameworkOptionItems(data=[ModelOption(framework='tensorrt', display_framework='TensorRT', devices=[DeviceInfo(device_name='AWS-T4', display_device_name='NVIDIA AWS-T4', display_brand_name='NVIDIA', software_versions=[], data_types=['FP16'], hardware_types=[]), DeviceInfo(device_name='Jetson-AGX-Orin', display_device_name='NVIDIA Jetson AGX Orin', display_brand_name='NVIDIA', software_versions=[SoftwareVersionInfo(software_version='5.0.1-b118', display_software_version='Jetpack 5.0.1')], data_types=['FP16'], hardware_types=[]), DeviceInfo(device_name='Jetson-Nano', display_device_name='NVIDIA Jetson Nano', display_brand_name='NVIDIA', software_versions=[SoftwareVersionInfo(software_version='4.4.1-b50', display_software_version='Jetpack 4.4.1'), SoftwareVersionInfo(software_version='4.6-b199', display_software_version='Jetpack 4.6')], data_types=['FP16'], hardware_types=[]), DeviceInfo(device_name='Jetson-Nx', display_device_name='NVIDIA Jetson Xavier NX', display_brand_name='NVIDIA', software_versions=[SoftwareVersionInfo(software_version='4.6-b199', display_software_version='Jetpack 4.6'), SoftwareVersionInfo(software_version='5.0.2-b231', display_software_version='Jetpack 5.0.2')], data_types=['FP16'], hardware_types=[]), DeviceInfo(device_name='Jetson-Orin-Nano', display_device_name='NVIDIA Jetson Orin Nano', display_brand_name='NVIDIA', software_versions=[SoftwareVersionInfo(software_version='6.0-b52', display_software_version='Jetpack 6.0')], data_types=['FP16'], hardware_types=[]), DeviceInfo(device_name='Jetson-Tx2', display_device_name='NVIDIA Jetson Tx2', display_brand_name='NVIDIA', software_versions=[SoftwareVersionInfo(software_version='4.6-b199', display_software_version='Jetpack 4.6')], data_types=['FP16'], hardware_types=[]), DeviceInfo(device_name='Jetson-Xavier', display_device_name='NVIDIA Jetson AGX Xavier', display_brand_name='NVIDIA', software_versions=[SoftwareVersionInfo(software_version='4.6-b199', display_software_version='Jetpack 4.6')], data_types=['FP16'], hardware_types=[])]), ModelOption(framework='tensorflow_lite', display_framework='Tensorflow Lite', devices=[DeviceInfo(device_name='Arm Virtual Hardware Ethos-U Series', display_device_name='Arm Virtual Hardware Corstone-300 (Ethos-U55/U65)', display_brand_name='Arm', software_versions=[], data_types=['INT8'], hardware_types=[]), DeviceInfo(device_name='Ensemble-E7-DevKit-Gen2', display_device_name='Alif Ensemble DevKit-E7 Gen2 (Arm Cortex-M55+Ethos-U55)', display_brand_name='Arm', software_versions=[], data_types=['INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi-Zero2W', display_device_name='RaspberryPi Zero2W', display_brand_name='RaspberryPi', software_versions=[], data_types=['FP16', 'INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi-ZeroW', display_device_name='RaspberryPi ZeroW', display_brand_name='RaspberryPi', software_versions=[], data_types=['FP16', 'INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi2B', display_device_name='Raspberry Pi 2B', display_brand_name='RaspberryPi', software_versions=[], data_types=['FP16', 'INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi3B', display_device_name='Raspberry Pi 3B', display_brand_name='RaspberryPi', software_versions=[], data_types=['FP16', 'INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi3BPlus', display_device_name='Raspberry Pi 3B+', display_brand_name='RaspberryPi', software_versions=[], data_types=['FP16', 'INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi4B', display_device_name='Raspberry Pi 4B', display_brand_name='RaspberryPi', software_versions=[], data_types=['FP16', 'INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi5', display_device_name='RaspberryPi 5 (Arm Cortex-A76)', display_brand_name='RaspberryPi', software_ ...
# 2025-02-13 04:15:31.839 | INFO     | netspresso.trainer.trainer:train:626 - Removed /tmp/temp_np_trainer_configs_3_udkmxr folder.
# 2025-02-13 04:15:31.843 | INFO     | netspresso.trainer.trainer:train:629 - Files in outputs/qai-hub-yolox-s (1)/version_0 were moved to outputs/qai-hub-yolox-s (1).
# 2025-02-13 04:15:31.899 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/metadata.json

# %% [markdown]
# # 2. Benchmark the trained model on QCS6490

# %% [markdown]
# ## 2-0. Create calibration datasets

# %% [markdown]
# ### Using good, representative input samples for calibration helps improve performance on target hardware and retains model accuracy

# %%
import cv2
from glob import glob

import numpy as np
from netspresso.inferencer.preprocessors.base import Preprocessor

preprocess_list = [
    {
        "name": "resize",
        "size": IMG_SIZE,
        "interpolation": "bilinear",
        "max_size": None,
        "resize_criteria": "long",
    },
    {
        "name": "pad",
        "size": IMG_SIZE,
        "fill": 114,
    }
]

preprocessor = Preprocessor(preprocess_list)

dataset_path = "./traffic-sign/images/train"
num_dataset = 100
image_paths = glob(f"{dataset_path}/*.jpg")[:num_dataset]

inputs_array = []

for image_path in image_paths:
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = preprocessor(img)
    img = np.transpose(img, (0, 3, 1, 2))
    inputs_array.append(img)

# %%
np.array(inputs_array).shape
# Out:
# (100, 1, 3, 512, 512)

# %% [markdown]
# ## 2-1. Quantize the trained model using Qualcomm AI Hub

# %% [markdown]
# ### This provides an ONNX model with weights quantized to int8 and activations quantized to int8.

# %%
import time

from netspresso.np_qai.options import CompileOptions, Runtime, ComputeUnit, ProfileOptions, TfliteOptions, QuantizePrecision

quantizer = np_qai.quantizer()

calibration_data = {"images": inputs_array}

quantized_result = quantizer.quantize_model(
    input_model_path=trained_result.best_onnx_model_path,
    output_dir=f"{trained_result.output_dir}/quantized/trained_model_w8a8",
    calibration_data=calibration_data,
    weights_dtype=QuantizePrecision.INT8,
    activations_dtype=QuantizePrecision.INT8,
    job_name="detection_yolox_s_w8a8",
)
print("Quantization task started")

# Monitor task status
while True:
    status = quantizer.get_quantize_task_status(quantized_result.quantize_info.quantize_task_uuid)
    if status.finished:
        quantized_result = quantizer.update_quantize_task(quantized_result)
        print("Quantization task completed")
        break
    else:
        time.sleep(30)
        print("Quantization task is still running")
# Out:
# 2025-02-13 04:15:33.941 | INFO     | netspresso.utils.file:create_unique_folder:82 - The folder has been created. Local Path: /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/quantized/trained_model_w8a8
# 2025-02-13 04:15:33.944 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/quantized/trained_model_w8a8/metadata.json
# Uploading detection_yolox_s_best.onnx
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 34.1M/34.1M [00:05<00:00, 6.47MB/s]
# Uploading dataset: 45.6MB [00:05, 8.83MB/s]                                                                                                                                                                       9.25MB/s]
# 2025-02-13 04:15:53.255 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/quantized/trained_model_w8a8/metadata.json
# Scheduled quantize job (j5ww32q65) successfully. To see the status and results:
#     https://app.aihub.qualcomm.com/jobs/j5ww32q65/
#
# Quantization task started
# Quantization task is still running
# Quantization task is still running
# Quantization task is still running
# 2025-02-13 04:17:26.970 | INFO     | netspresso.np_qai.quantizer:update_quantize_task:51 - ✅ SUCCESS
# trained_model_w8a8.onnx: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 34.4M/34.4M [00:01<00:00, 24.0MB/s]
# Downloaded model to /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/quantized/trained_model_w8a8/trained_model_w8a8.onnx
# 2025-02-13 04:17:30.013 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/quantized/trained_model_w8a8/metadata.json
# Quantization task completed

# %% [markdown]
# ## 2-2. Compile and Optimize the quantized model using Qualcomm AI Hub

# %%
from netspresso.np_qai import Device
from netspresso.np_qai.options import CompileOptions, Runtime, ComputeUnit, ProfileOptions, TfliteOptions, QuantizeFullType

converter = np_qai.converter()

convert_options = CompileOptions(
    target_runtime=Runtime.TFLITE,
    compute_unit=[ComputeUnit.NPU],
    quantize_full_type=QuantizeFullType.INT8,
    quantize_io=True,
    quantize_io_type=QuantizeFullType.INT8,
)

converted_result = converter.convert_model(
    input_model_path=quantized_result.quantized_model_path,
    output_dir=f"{trained_result.output_dir}/converted/quantized_model_tflite",
    target_device_name=Device("QCS6490 (Proxy)"),
    options=convert_options,
    input_shapes=dict(image=(1, 3, IMG_SIZE, IMG_SIZE)),
    job_name=f"detection_yolox_s_tflite",
)

print("Conversion task started")

# Monitor task status
while True:
    status = converter.get_convert_task_status(converted_result.convert_task_info.convert_task_uuid)
    if status.finished:
        converted_result = converter.update_convert_task(converted_result)
        print("Conversion task completed")
        break
    else:
        time.sleep(30)
        print("Conversion task is still running")
# Out:
# 2025-02-13 04:17:30.037 | INFO     | netspresso.utils.file:create_unique_folder:82 - The folder has been created. Local Path: /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/converted/quantized_model_tflite
# 2025-02-13 04:17:30.041 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/converted/quantized_model_tflite/metadata.json
# Uploading trained_model_w8a8.onnx
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 34.4M/34.4M [00:03<00:00, 9.71MB/s]
# 2025-02-13 04:17:35.499 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/converted/quantized_model_tflite/metadata.json
# Scheduled compile job (jp12wye2g) successfully. To see the status and results:
#     https://app.aihub.qualcomm.com/jobs/jp12wye2g/
#
# Conversion task started
# Conversion task is still running
# Conversion task is still running
# 2025-02-13 04:18:38.119 | INFO     | netspresso.np_qai.converter:update_convert_task:58 - ✅ SUCCESS
# quantized_model_tflite.tflite: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8.89M/8.89M [00:00<00:00, 10.3MB/s]
# Downloaded model to /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/converted/quantized_model_tflite/quantized_model_tflite.tflite
# 2025-02-13 04:18:40.768 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/converted/quantized_model_tflite/metadata.json
# Conversion task completed

# %% [markdown]
# ## 2-3. Benchmark the performance on-device using Qualcomm AI Hub

# %% [markdown]
# ### Visit your job on [Qualcomm AI Hub](https://app.aihub.qualcomm.com/jobs/) to see other inference metrics like memory usage, load time, layer by layer analysis and model visualization.

# %%
benchmarker = np_qai.benchmarker()

benchmark_options = ProfileOptions(
    compute_unit=[ComputeUnit.NPU],
    tflite_options=TfliteOptions(number_of_threads=4),
)

benchmark_result = benchmarker.benchmark_model(
    input_model_path=converted_result.converted_model_path,
    target_device_name=Device("QCS6490 (Proxy)"),
    options=benchmark_options,
)

# Monitor task status
while True:
    status = benchmarker.get_benchmark_task_status(benchmark_result.benchmark_task_info.benchmark_task_uuid)
    if status.finished:
        benchmark_result = benchmarker.update_benchmark_task(benchmark_result)
        print("Benchmark task completed")
        break
    else:
        time.sleep(30)
        print("Benchmark task is still running")

print(benchmark_result)
# Out:
# 2025-02-13 04:18:40.791 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/converted/quantized_model_tflite/benchmark.json
# Uploading quantized_model_tflite.tflite
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8.89M/8.89M [00:02<00:00, 3.27MB/s]
# 2025-02-13 04:18:45.240 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/converted/quantized_model_tflite/benchmark.json
# Scheduled profile job (j5ww32q35) successfully. To see the status and results:
#     https://app.aihub.qualcomm.com/jobs/j5ww32q35/
#
# Benchmark task is still running
# Benchmark task is still running
# Benchmark task is still running
# Benchmark task is still running
# Benchmark task is still running
# Benchmark task is still running
# 2025-02-13 04:21:50.933 | INFO     | netspresso.np_qai.benchmarker:update_benchmark_task:86 - ✅ SUCCESS
# 2025-02-13 04:21:51.485 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/converted/quantized_model_tflite/benchmark.json
# Benchmark task completed
# BenchmarkerMetadata(status=<Status.COMPLETED: 'completed'>, error_detail=ExceptionDetail(data=AdditionalData(origin='', error_log='', link=None), error_code='', name='', message=''), task_type=<TaskType.BENCHMARK: 'benchmark'>, input_model_path='/root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/converted/quantized_model_tflite/quantized_model_tflite.tflite', benchmark_task_info=BenchmarkTaskInfo(benchmark_task_uuid='j5ww32q35', framework=<Framework.TFLITE: 'tensorflow_lite'>, display_framework='Tensorflow Lite', device_name='QCS6490 (Proxy)', display_device_name='QCS6490 (Proxy)', display_brand_name='', software_version='', display_software_version='', data_type='', hardware_type=''), benchmark_result=BenchmarkResult(memory_footprint=176136192, memory_footprint_gpu=None, memory_footprint_cpu=None, power_consumption=None, ram_size=None, latency=21.576, file_size=None))

# %%
print(f"Latency of trained model: {benchmark_result.benchmark_result.latency} ms")
# Out:
# Latency of trained model: 21.576 ms

# %% [markdown]
# # 3. Optimize the trained model using Compressor

# %% [markdown]
# ## 3-1. Run automatic compression

# %%
ratios = [0.3, 0.5, 0.7]

compressor = netspresso.compressor_v2()
compressed_results = {}

for ratio in ratios:
    _compressed_result = compressor.automatic_compression(
        input_model_path=trained_result.best_fx_model_path,
        output_dir=f"{trained_result.output_dir}/compressed/pruning_{ratio}",
        input_shapes=trained_result.model_info.input_shapes,
        compression_ratio=ratio,
    )
    compressed_results[ratio] = _compressed_result
# Out:
# 2025-02-13 04:44:28.055 | INFO     | netspresso.utils.file:create_unique_folder:82 - The folder has been created. Local Path: /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/compressed/pruning_0.3
# 2025-02-13 04:44:28.067 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/compressed/pruning_0.3/metadata.json
# 2025-02-13 04:44:28.069 | INFO     | netspresso.compressor.v2.compressor:automatic_compression:559 - Compressing automatic-based model...
# 2025-02-13 04:44:28.276 | INFO     | netspresso.clients.auth.v2.client:get_credit:60 - Successfully got user credit
# 2025-02-13 04:44:28.279 | INFO     | netspresso.compressor.v2.compressor:upload_model:168 - Uploading Model...
# Uploading model: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 34.4M/34.4M [00:03<00:00, 9.82MB/s]
# 2025-02-13 04:44:36.944 | INFO     | netspresso.compressor.v2.compressor:upload_model:205 - Upload model successfully. Model ID: 81736287-434a-4ce4-9b6c-516b777cd83e
# 2025-02-13 04:44:36.952 | INFO     | netspresso.compressor.v2.compressor:automatic_compression:567 - Compressing model...
# 2025-02-13 04:44:52.694 | INFO     | netspresso.compressor.v2.compressor:download_model:237 - Downloading model...
# 2025-02-13 04:44:53.186 | INFO     | netspresso.compressor.v2.compressor:download_model:244 - Model downloaded at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/compressed/pruning_0.3/pruning_0.3.pt
# 2025-02-13 04:44:53.190 | INFO     | netspresso.compressor.v2.compressor:get_model:217 - Getting model...
# 2025-02-13 04:44:53.364 | INFO     | netspresso.compressor.v2.compressor:get_model:225 - Get model successfully.
# /opt/conda/lib/python3.10/site-packages/torch/onnx/_internal/jit_utils.py:258: UserWarning: The shape inference of prim::Constant type is missing, so it may result in wrong shape inference for the exported graph. Please consider adding it in symbolic function. (Triggered internally at ../torch/csrc/jit/passes/onnx/shape_type_inference.cpp:1884.)
#   _C._jit_pass_onnx_node_shape_type_inference(node, params_dict, opset_version)
# /opt/conda/lib/python3.10/site-packages/torch/onnx/utils.py:687: UserWarning: The shape inference of prim::Constant type is missing, so it may result in wrong shape inference for the exported graph. Please consider adding it in symbolic function. (Triggered internally at ../torch/csrc/jit/passes/onnx/shape_type_inference.cpp:1884.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# /opt/conda/lib/python3.10/site-packages/torch/onnx/utils.py:1178: UserWarning: The shape inference of prim::Constant type is missing, so it may result in wrong shape inference for the exported graph. Please consider adding it in symbolic function. (Triggered internally at ../torch/csrc/jit/passes/onnx/shape_type_inference.cpp:1884.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# 2025-02-13 04:44:55.038 | INFO     | netspresso.compressor.utils.onnx:_export_onnx:29 - ONNX model converting and saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/compressed/pruning_0.3/pruning_0.3.onnx
# 2025-02-13 04:44:55.041 | INFO     | netspresso.clients.launcher.v2.converter:read_framework_options:175 - Request Convert options
# 2025-02-13 04:44:55.209 | INFO     | netspresso.clients.launcher.v2.converter:read_framework_options:180 - Request Convert Task Options by model_framework: ResponseConvertFrameworkOptionItems(data=[ModelOption(framework='tensorrt', display_framework='TensorRT', devices=[DeviceInfo(device_name='AWS-T4', display_device_name='NVIDIA AWS-T4', display_brand_name='NVIDIA', software_versions=[], data_types=['FP16'], hardware_types=[]), DeviceInfo(device_name='Jetson-AGX-Orin', display_device_name='NVIDIA Jetson AGX Orin', display_brand_name='NVIDIA', software_versions=[SoftwareVersionInfo(software_version='5.0.1-b118', display_software_version='Jetpack 5.0.1')], data_types=['FP16'], hardware_types=[]), DeviceInfo(device_name='Jetson-Nano', display_device_name='NVIDIA Jetson Nano', display_brand_name='NVIDIA', software_versions=[SoftwareVersionInfo(software_version='4.4.1-b50', display_software_version='Jetpack 4.4.1'), SoftwareVersionInfo(software_version='4.6-b199', display_software_version='Jetpack 4.6')], data_types=['FP16'], hardware_types=[]), DeviceInfo(device_name='Jetson-Nx', display_device_name='NVIDIA Jetson Xavier NX', display_brand_name='NVIDIA', software_versions=[SoftwareVersionInfo(software_version='4.6-b199', display_software_version='Jetpack 4.6'), SoftwareVersionInfo(software_version='5.0.2-b231', display_software_version='Jetpack 5.0.2')], data_types=['FP16'], hardware_types=[]), DeviceInfo(device_name='Jetson-Orin-Nano', display_device_name='NVIDIA Jetson Orin Nano', display_brand_name='NVIDIA', software_versions=[SoftwareVersionInfo(software_version='6.0-b52', display_software_version='Jetpack 6.0')], data_types=['FP16'], hardware_types=[]), DeviceInfo(device_name='Jetson-Tx2', display_device_name='NVIDIA Jetson Tx2', display_brand_name='NVIDIA', software_versions=[SoftwareVersionInfo(software_version='4.6-b199', display_software_version='Jetpack 4.6')], data_types=['FP16'], hardware_types=[]), DeviceInfo(device_name='Jetson-Xavier', display_device_name='NVIDIA Jetson AGX Xavier', display_brand_name='NVIDIA', software_versions=[SoftwareVersionInfo(software_version='4.6-b199', display_software_version='Jetpack 4.6')], data_types=['FP16'], hardware_types=[])]), ModelOption(framework='tensorflow_lite', display_framework='Tensorflow Lite', devices=[DeviceInfo(device_name='Arm Virtual Hardware Ethos-U Series', display_device_name='Arm Virtual Hardware Corstone-300 (Ethos-U55/U65)', display_brand_name='Arm', software_versions=[], data_types=['INT8'], hardware_types=[]), DeviceInfo(device_name='Ensemble-E7-DevKit-Gen2', display_device_name='Alif Ensemble DevKit-E7 Gen2 (Arm Cortex-M55+Ethos-U55)', display_brand_name='Arm', software_versions=[], data_types=['INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi-Zero2W', display_device_name='RaspberryPi Zero2W', display_brand_name='RaspberryPi', software_versions=[], data_types=['FP16', 'INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi-ZeroW', display_device_name='RaspberryPi ZeroW', display_brand_name='RaspberryPi', software_versions=[], data_types=['FP16', 'INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi2B', display_device_name='Raspberry Pi 2B', display_brand_name='RaspberryPi', software_versions=[], data_types=['FP16', 'INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi3B', display_device_name='Raspberry Pi 3B', display_brand_name='RaspberryPi', software_versions=[], data_types=['FP16', 'INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi3BPlus', display_device_name='Raspberry Pi 3B+', display_brand_name='RaspberryPi', software_versions=[], data_types=['FP16', 'INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi4B', display_device_name='Raspberry Pi 4B', display_brand_name='RaspberryPi', software_versions=[], data_types=['FP16', 'INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi5', display_device_name='RaspberryPi 5 (Arm Cortex-A76)', display_brand_name='RaspberryPi', software_ ...
# 2025-02-13 04:44:55.416 | INFO     | netspresso.clients.auth.v2.client:get_credit:60 - Successfully got user credit
# 2025-02-13 04:44:55.418 | INFO     | netspresso.base:print_remaining_credit:33 - 25 credits have been consumed. Remaining Credit: 24625
# 2025-02-13 04:44:55.419 | INFO     | netspresso.compressor.v2.compressor:automatic_compression:580 - Automatic compression successfully. Compressed Model ID: e34d3e6e-e7cf-49df-a56a-a08f743958cb
# 2025-02-13 04:44:55.438 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/compressed/pruning_0.3/metadata.json
# 2025-02-13 04:44:55.442 | INFO     | netspresso.utils.file:create_unique_folder:90 - The folder has been created. Local Path: /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/compressed/pruning_0.5 (1)
# 2025-02-13 04:44:55.451 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/compressed/pruning_0.5 (1)/metadata.json
# 2025-02-13 04:44:55.453 | INFO     | netspresso.compressor.v2.compressor:automatic_compression:559 - Compressing automatic-based model...
# 2025-02-13 04:44:55.654 | INFO     | netspresso.clients.auth.v2.client:get_credit:60 - Successfully got user credit
# 2025-02-13 04:44:55.656 | INFO     | netspresso.compressor.v2.compressor:upload_model:168 - Uploading Model...
# Uploading model: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 34.4M/34.4M [00:03<00:00, 9.81MB/s]
# 2025-02-13 04:45:04.361 | INFO     | netspresso.compressor.v2.compressor:upload_model:205 - Upload model successfully. Model ID: dae06700-8707-4c51-97bb-52ba98b16bf9
# 2025-02-13 04:45:04.369 | INFO     | netspresso.compressor.v2.compressor:automatic_compression:567 - Compressing model...
# 2025-02-13 04:45:20.062 | INFO     | netspresso.compressor.v2.compressor:download_model:237 - Downloading model...
# 2025-02-13 04:45:20.434 | INFO     | netspresso.compressor.v2.compressor:download_model:244 - Model downloaded at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/compressed/pruning_0.5 (1)/pruning_0.5 (1).pt
# 2025-02-13 04:45:20.439 | INFO     | netspresso.compressor.v2.compressor:get_model:217 - Getting model...
# 2025-02-13 04:45:20.611 | INFO     | netspresso.compressor.v2.compressor:get_model:225 - Get model successfully.
# 2025-02-13 04:45:22.136 | INFO     | netspresso.compressor.utils.onnx:_export_onnx:29 - ONNX model converting and saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/compressed/pruning_0.5 (1)/pruning_0.5 (1).onnx
# 2025-02-13 04:45:22.139 | INFO     | netspresso.clients.launcher.v2.converter:read_framework_options:175 - Request Convert options
# 2025-02-13 04:45:22.298 | INFO     | netspresso.clients.launcher.v2.converter:read_framework_options:180 - Request Convert Task Options by model_framework: ResponseConvertFrameworkOptionItems(data=[ModelOption(framework='tensorrt', display_framework='TensorRT', devices=[DeviceInfo(device_name='AWS-T4', display_device_name='NVIDIA AWS-T4', display_brand_name='NVIDIA', software_versions=[], data_types=['FP16'], hardware_types=[]), DeviceInfo(device_name='Jetson-AGX-Orin', display_device_name='NVIDIA Jetson AGX Orin', display_brand_name='NVIDIA', software_versions=[SoftwareVersionInfo(software_version='5.0.1-b118', display_software_version='Jetpack 5.0.1')], data_types=['FP16'], hardware_types=[]), DeviceInfo(device_name='Jetson-Nano', display_device_name='NVIDIA Jetson Nano', display_brand_name='NVIDIA', software_versions=[SoftwareVersionInfo(software_version='4.4.1-b50', display_software_version='Jetpack 4.4.1'), SoftwareVersionInfo(software_version='4.6-b199', display_software_version='Jetpack 4.6')], data_types=['FP16'], hardware_types=[]), DeviceInfo(device_name='Jetson-Nx', display_device_name='NVIDIA Jetson Xavier NX', display_brand_name='NVIDIA', software_versions=[SoftwareVersionInfo(software_version='4.6-b199', display_software_version='Jetpack 4.6'), SoftwareVersionInfo(software_version='5.0.2-b231', display_software_version='Jetpack 5.0.2')], data_types=['FP16'], hardware_types=[]), DeviceInfo(device_name='Jetson-Orin-Nano', display_device_name='NVIDIA Jetson Orin Nano', display_brand_name='NVIDIA', software_versions=[SoftwareVersionInfo(software_version='6.0-b52', display_software_version='Jetpack 6.0')], data_types=['FP16'], hardware_types=[]), DeviceInfo(device_name='Jetson-Tx2', display_device_name='NVIDIA Jetson Tx2', display_brand_name='NVIDIA', software_versions=[SoftwareVersionInfo(software_version='4.6-b199', display_software_version='Jetpack 4.6')], data_types=['FP16'], hardware_types=[]), DeviceInfo(device_name='Jetson-Xavier', display_device_name='NVIDIA Jetson AGX Xavier', display_brand_name='NVIDIA', software_versions=[SoftwareVersionInfo(software_version='4.6-b199', display_software_version='Jetpack 4.6')], data_types=['FP16'], hardware_types=[])]), ModelOption(framework='tensorflow_lite', display_framework='Tensorflow Lite', devices=[DeviceInfo(device_name='Arm Virtual Hardware Ethos-U Series', display_device_name='Arm Virtual Hardware Corstone-300 (Ethos-U55/U65)', display_brand_name='Arm', software_versions=[], data_types=['INT8'], hardware_types=[]), DeviceInfo(device_name='Ensemble-E7-DevKit-Gen2', display_device_name='Alif Ensemble DevKit-E7 Gen2 (Arm Cortex-M55+Ethos-U55)', display_brand_name='Arm', software_versions=[], data_types=['INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi-Zero2W', display_device_name='RaspberryPi Zero2W', display_brand_name='RaspberryPi', software_versions=[], data_types=['FP16', 'INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi-ZeroW', display_device_name='RaspberryPi ZeroW', display_brand_name='RaspberryPi', software_versions=[], data_types=['FP16', 'INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi2B', display_device_name='Raspberry Pi 2B', display_brand_name='RaspberryPi', software_versions=[], data_types=['FP16', 'INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi3B', display_device_name='Raspberry Pi 3B', display_brand_name='RaspberryPi', software_versions=[], data_types=['FP16', 'INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi3BPlus', display_device_name='Raspberry Pi 3B+', display_brand_name='RaspberryPi', software_versions=[], data_types=['FP16', 'INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi4B', display_device_name='Raspberry Pi 4B', display_brand_name='RaspberryPi', software_versions=[], data_types=['FP16', 'INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi5', display_device_name='RaspberryPi 5 (Arm Cortex-A76)', display_brand_name='RaspberryPi', software_ ...
# 2025-02-13 04:45:22.477 | INFO     | netspresso.clients.auth.v2.client:get_credit:60 - Successfully got user credit
# 2025-02-13 04:45:22.478 | INFO     | netspresso.base:print_remaining_credit:33 - 25 credits have been consumed. Remaining Credit: 24600
# 2025-02-13 04:45:22.480 | INFO     | netspresso.compressor.v2.compressor:automatic_compression:580 - Automatic compression successfully. Compressed Model ID: 3661a17f-2e68-417f-a2a7-93e96baf49ae
# 2025-02-13 04:45:22.499 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/compressed/pruning_0.5 (1)/metadata.json
# 2025-02-13 04:45:22.503 | INFO     | netspresso.utils.file:create_unique_folder:90 - The folder has been created. Local Path: /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/compressed/pruning_0.7 (1)
# 2025-02-13 04:45:22.512 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/compressed/pruning_0.7 (1)/metadata.json
# 2025-02-13 04:45:22.514 | INFO     | netspresso.compressor.v2.compressor:automatic_compression:559 - Compressing automatic-based model...
# 2025-02-13 04:45:22.685 | INFO     | netspresso.clients.auth.v2.client:get_credit:60 - Successfully got user credit
# 2025-02-13 04:45:22.688 | INFO     | netspresso.compressor.v2.compressor:upload_model:168 - Uploading Model...
# Uploading model: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 34.4M/34.4M [00:03<00:00, 9.83MB/s]
# 2025-02-13 04:45:31.423 | INFO     | netspresso.compressor.v2.compressor:upload_model:205 - Upload model successfully. Model ID: c281925c-bceb-4377-ac34-6ab8b0fbc19f
# 2025-02-13 04:45:31.431 | INFO     | netspresso.compressor.v2.compressor:automatic_compression:567 - Compressing model...
# 2025-02-13 04:45:46.349 | INFO     | netspresso.compressor.v2.compressor:download_model:237 - Downloading model...
# 2025-02-13 04:45:46.659 | INFO     | netspresso.compressor.v2.compressor:download_model:244 - Model downloaded at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/compressed/pruning_0.7 (1)/pruning_0.7 (1).pt
# 2025-02-13 04:45:46.662 | INFO     | netspresso.compressor.v2.compressor:get_model:217 - Getting model...
# 2025-02-13 04:45:46.842 | INFO     | netspresso.compressor.v2.compressor:get_model:225 - Get model successfully.
# 2025-02-13 04:45:48.326 | INFO     | netspresso.compressor.utils.onnx:_export_onnx:29 - ONNX model converting and saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/compressed/pruning_0.7 (1)/pruning_0.7 (1).onnx
# 2025-02-13 04:45:48.329 | INFO     | netspresso.clients.launcher.v2.converter:read_framework_options:175 - Request Convert options
# 2025-02-13 04:45:48.483 | INFO     | netspresso.clients.launcher.v2.converter:read_framework_options:180 - Request Convert Task Options by model_framework: ResponseConvertFrameworkOptionItems(data=[ModelOption(framework='tensorrt', display_framework='TensorRT', devices=[DeviceInfo(device_name='AWS-T4', display_device_name='NVIDIA AWS-T4', display_brand_name='NVIDIA', software_versions=[], data_types=['FP16'], hardware_types=[]), DeviceInfo(device_name='Jetson-AGX-Orin', display_device_name='NVIDIA Jetson AGX Orin', display_brand_name='NVIDIA', software_versions=[SoftwareVersionInfo(software_version='5.0.1-b118', display_software_version='Jetpack 5.0.1')], data_types=['FP16'], hardware_types=[]), DeviceInfo(device_name='Jetson-Nano', display_device_name='NVIDIA Jetson Nano', display_brand_name='NVIDIA', software_versions=[SoftwareVersionInfo(software_version='4.4.1-b50', display_software_version='Jetpack 4.4.1'), SoftwareVersionInfo(software_version='4.6-b199', display_software_version='Jetpack 4.6')], data_types=['FP16'], hardware_types=[]), DeviceInfo(device_name='Jetson-Nx', display_device_name='NVIDIA Jetson Xavier NX', display_brand_name='NVIDIA', software_versions=[SoftwareVersionInfo(software_version='4.6-b199', display_software_version='Jetpack 4.6'), SoftwareVersionInfo(software_version='5.0.2-b231', display_software_version='Jetpack 5.0.2')], data_types=['FP16'], hardware_types=[]), DeviceInfo(device_name='Jetson-Orin-Nano', display_device_name='NVIDIA Jetson Orin Nano', display_brand_name='NVIDIA', software_versions=[SoftwareVersionInfo(software_version='6.0-b52', display_software_version='Jetpack 6.0')], data_types=['FP16'], hardware_types=[]), DeviceInfo(device_name='Jetson-Tx2', display_device_name='NVIDIA Jetson Tx2', display_brand_name='NVIDIA', software_versions=[SoftwareVersionInfo(software_version='4.6-b199', display_software_version='Jetpack 4.6')], data_types=['FP16'], hardware_types=[]), DeviceInfo(device_name='Jetson-Xavier', display_device_name='NVIDIA Jetson AGX Xavier', display_brand_name='NVIDIA', software_versions=[SoftwareVersionInfo(software_version='4.6-b199', display_software_version='Jetpack 4.6')], data_types=['FP16'], hardware_types=[])]), ModelOption(framework='tensorflow_lite', display_framework='Tensorflow Lite', devices=[DeviceInfo(device_name='Arm Virtual Hardware Ethos-U Series', display_device_name='Arm Virtual Hardware Corstone-300 (Ethos-U55/U65)', display_brand_name='Arm', software_versions=[], data_types=['INT8'], hardware_types=[]), DeviceInfo(device_name='Ensemble-E7-DevKit-Gen2', display_device_name='Alif Ensemble DevKit-E7 Gen2 (Arm Cortex-M55+Ethos-U55)', display_brand_name='Arm', software_versions=[], data_types=['INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi-Zero2W', display_device_name='RaspberryPi Zero2W', display_brand_name='RaspberryPi', software_versions=[], data_types=['FP16', 'INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi-ZeroW', display_device_name='RaspberryPi ZeroW', display_brand_name='RaspberryPi', software_versions=[], data_types=['FP16', 'INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi2B', display_device_name='Raspberry Pi 2B', display_brand_name='RaspberryPi', software_versions=[], data_types=['FP16', 'INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi3B', display_device_name='Raspberry Pi 3B', display_brand_name='RaspberryPi', software_versions=[], data_types=['FP16', 'INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi3BPlus', display_device_name='Raspberry Pi 3B+', display_brand_name='RaspberryPi', software_versions=[], data_types=['FP16', 'INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi4B', display_device_name='Raspberry Pi 4B', display_brand_name='RaspberryPi', software_versions=[], data_types=['FP16', 'INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi5', display_device_name='RaspberryPi 5 (Arm Cortex-A76)', display_brand_name='RaspberryPi', software_ ...
# 2025-02-13 04:45:48.651 | INFO     | netspresso.clients.auth.v2.client:get_credit:60 - Successfully got user credit
# 2025-02-13 04:45:48.653 | INFO     | netspresso.base:print_remaining_credit:33 - 25 credits have been consumed. Remaining Credit: 24575
# 2025-02-13 04:45:48.655 | INFO     | netspresso.compressor.v2.compressor:automatic_compression:580 - Automatic compression successfully. Compressed Model ID: 9572670d-c7e5-4ee4-9b6a-63c131466b24
# 2025-02-13 04:45:48.674 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/compressed/pruning_0.7 (1)/metadata.json

# %% [markdown]
# ## 3-2. Quantize all the compressed models using Qualcomm AI Hub

# %%
quantize_tasks = {}
completed_quantize_tasks = set()

for ratio in ratios:
    _quantize_task = quantizer.quantize_model(
        input_model_path=compressed_results[ratio].compressed_onnx_model_path,
        output_dir=f"{trained_result.output_dir}/quantized/pruning_{ratio}_w8a8",
        calibration_data=calibration_data,
        weights_dtype=QuantizePrecision.INT8,
        activations_dtype=QuantizePrecision.INT8,
    )
    quantize_tasks[ratio] = _quantize_task
    print(f"Compressed model({ratio}) quantize task started")

while len(completed_quantize_tasks) < len(ratios):
    for ratio in ratios:
        if ratio not in completed_quantize_tasks:
            status = quantizer.get_quantize_task_status(quantize_tasks[ratio].quantize_info.quantize_task_uuid)
            if status.finished:
                quantize_tasks[ratio] = quantizer.update_quantize_task(quantize_tasks[ratio])
                completed_quantize_tasks.add(ratio)
                print(f"Compressed model({ratio}) quantize task completed")
            else:
                time.sleep(30)
                print(f"Compressed model({ratio}) quantize task is still running")

print("All tasks completed!")
# Out:
# 2025-02-13 04:45:48.693 | INFO     | netspresso.utils.file:create_unique_folder:82 - The folder has been created. Local Path: /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/quantized/pruning_0.3_w8a8
# 2025-02-13 04:45:48.698 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/quantized/pruning_0.3_w8a8/metadata.json
# Uploading pruning_0.3.onnx
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 17.1M/17.1M [00:01<00:00, 9.39MB/s]
# Uploading dataset: 45.6MB [00:04, 10.1MB/s]                                                                                                                                                                       10.3MB/s]
# 2025-02-13 04:46:03.656 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/quantized/pruning_0.3_w8a8/metadata.json
# 2025-02-13 04:46:03.659 | INFO     | netspresso.utils.file:create_unique_folder:90 - The folder has been created. Local Path: /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/quantized/pruning_0.5_w8a8 (1)
# 2025-02-13 04:46:03.663 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/quantized/pruning_0.5_w8a8 (1)/metadata.json
# Scheduled quantize job (jgn0mlek5) successfully. To see the status and results:
#     https://app.aihub.qualcomm.com/jobs/jgn0mlek5/
#
# Compressed model(0.3) quantize task started
# Uploading pruning_0.5 (1).onnx
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8.96M/8.96M [00:01<00:00, 5.57MB/s]
# Uploading dataset: 45.6MB [00:04, 9.77MB/s]                                                                                                                                                                       11.0MB/s]
# 2025-02-13 04:46:17.350 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/quantized/pruning_0.5_w8a8 (1)/metadata.json
# 2025-02-13 04:46:17.353 | INFO     | netspresso.utils.file:create_unique_folder:90 - The folder has been created. Local Path: /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/quantized/pruning_0.7_w8a8 (1)
# 2025-02-13 04:46:17.357 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/quantized/pruning_0.7_w8a8 (1)/metadata.json
# Scheduled quantize job (jpr628y0p) successfully. To see the status and results:
#     https://app.aihub.qualcomm.com/jobs/jpr628y0p/
#
# Compressed model(0.5) quantize task started
# Uploading pruning_0.7 (1).onnx
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3.33M/3.33M [00:01<00:00, 2.41MB/s]
# Uploading dataset: 45.6MB [00:04, 10.5MB/s]                                                                                                                                                                       8.72MB/s]
# 2025-02-13 04:46:30.873 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/quantized/pruning_0.7_w8a8 (1)/metadata.json
# Scheduled quantize job (jpyzjrd8g) successfully. To see the status and results:
#     https://app.aihub.qualcomm.com/jobs/jpyzjrd8g/
#
# Compressed model(0.7) quantize task started
# Compressed model(0.3) quantize task is still running
# Compressed model(0.5) quantize task is still running
# 2025-02-13 04:47:33.686 | INFO     | netspresso.np_qai.quantizer:update_quantize_task:51 - ✅ SUCCESS
# pruning_0.7_w8a8 (1).onnx: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3.51M/3.51M [00:00<00:00, 5.84MB/s]
# Downloaded model to /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/quantized/pruning_0.7_w8a8 (1)/pruning_0.7_w8a8 (1).onnx
# 2025-02-13 04:47:35.840 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/quantized/pruning_0.7_w8a8 (1)/metadata.json
# Compressed model(0.7) quantize task completed
# Compressed model(0.3) quantize task is still running
# 2025-02-13 04:48:07.865 | INFO     | netspresso.np_qai.quantizer:update_quantize_task:51 - ✅ SUCCESS
# pruning_0.5_w8a8 (1).onnx: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9.15M/9.15M [00:00<00:00, 10.7MB/s]
# Downloaded model to /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/quantized/pruning_0.5_w8a8 (1)/pruning_0.5_w8a8 (1).onnx
# 2025-02-13 04:48:10.201 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/quantized/pruning_0.5_w8a8 (1)/metadata.json
# Compressed model(0.5) quantize task completed
# 2025-02-13 04:48:11.099 | INFO     | netspresso.np_qai.quantizer:update_quantize_task:51 - ✅ SUCCESS
# pruning_0.3_w8a8.onnx: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 17.3M/17.3M [00:01<00:00, 16.8MB/s]
# Downloaded model to /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/quantized/pruning_0.3_w8a8/pruning_0.3_w8a8.onnx
# 2025-02-13 04:48:13.583 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/quantized/pruning_0.3_w8a8/metadata.json
# Compressed model(0.3) quantize task completed
# All tasks completed!

# %% [markdown]
# ## 3-3. Compile and Optimize all model using Qualcomm AI Hub

# %%
converter = np_qai.converter()

convert_tasks = {}
completed_convert_tasks = set()


for ratio in ratios:
    _converted_result = converter.convert_model(
        input_model_path=quantize_tasks[ratio].quantized_model_path,
        output_dir=f"{trained_result.output_dir}/converted/pruning_{ratio}",
        target_device_name=Device("QCS6490 (Proxy)"),
        options=convert_options,
        input_shapes=dict(image=(1, 3, IMG_SIZE, IMG_SIZE)),
        job_name=f"yolox_s_compressed_{ratio}_tflite",
    )
    convert_tasks[ratio] = _converted_result
    print(f"Quantized model({ratio}) convert task started")

while len(completed_convert_tasks) < len(ratios):
    for ratio in ratios:
        if ratio not in completed_convert_tasks:
            status = converter.get_convert_task_status(convert_tasks[ratio].convert_task_info.convert_task_uuid)
            if status.finished:
                convert_tasks[ratio] = converter.update_convert_task(convert_tasks[ratio])
                completed_convert_tasks.add(ratio)
                print(f"Quantized model({ratio}) convert task completed")
            else:
                time.sleep(30)
                print(f"Quantized model({ratio}) convert task is still running")

print("All tasks completed!")
# Out:
# 2025-02-13 04:48:13.612 | INFO     | netspresso.utils.file:create_unique_folder:82 - The folder has been created. Local Path: /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/converted/pruning_0.3
# 2025-02-13 04:48:13.616 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/converted/pruning_0.3/metadata.json
# Uploading pruning_0.3_w8a8.onnx
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 17.3M/17.3M [00:03<00:00, 5.62MB/s]
# 2025-02-13 04:48:18.643 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/converted/pruning_0.3/metadata.json
# 2025-02-13 04:48:18.646 | INFO     | netspresso.utils.file:create_unique_folder:90 - The folder has been created. Local Path: /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/converted/pruning_0.5 (1)
# 2025-02-13 04:48:18.650 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/converted/pruning_0.5 (1)/metadata.json
# Scheduled compile job (j5q0re2np) successfully. To see the status and results:
#     https://app.aihub.qualcomm.com/jobs/j5q0re2np/
#
# Quantized model(0.3) convert task started
# Uploading pruning_0.5_w8a8 (1).onnx
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9.15M/9.15M [00:02<00:00, 3.79MB/s]
# 2025-02-13 04:48:23.262 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/converted/pruning_0.5 (1)/metadata.json
# 2025-02-13 04:48:23.265 | INFO     | netspresso.utils.file:create_unique_folder:90 - The folder has been created. Local Path: /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/converted/pruning_0.7 (1)
# 2025-02-13 04:48:23.269 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/converted/pruning_0.7 (1)/metadata.json
# Scheduled compile job (jgl426kj5) successfully. To see the status and results:
#     https://app.aihub.qualcomm.com/jobs/jgl426kj5/
#
# Quantized model(0.5) convert task started
# Uploading pruning_0.7_w8a8 (1).onnx
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3.51M/3.51M [00:01<00:00, 2.37MB/s]
# 2025-02-13 04:48:26.534 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/converted/pruning_0.7 (1)/metadata.json
# Scheduled compile job (jp3n1vm35) successfully. To see the status and results:
#     https://app.aihub.qualcomm.com/jobs/jp3n1vm35/
#
# Quantized model(0.7) convert task started
# Quantized model(0.3) convert task is still running
# Quantized model(0.5) convert task is still running
# 2025-02-13 04:49:29.220 | INFO     | netspresso.np_qai.converter:update_convert_task:58 - ✅ SUCCESS
# pruning_0.7 (1).tflite: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1.00M/1.00M [00:00<00:00, 2.81MB/s]
# Downloaded model to /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/converted/pruning_0.7 (1)/pruning_0.7 (1).tflite
# 2025-02-13 04:49:31.044 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/converted/pruning_0.7 (1)/metadata.json
# Quantized model(0.7) convert task completed
# 2025-02-13 04:49:31.960 | INFO     | netspresso.np_qai.converter:update_convert_task:58 - ✅ SUCCESS
# pruning_0.3.tflite: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4.56M/4.56M [00:00<00:00, 6.51MB/s]
# Downloaded model to /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/converted/pruning_0.3/pruning_0.3.tflite
# 2025-02-13 04:49:34.182 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/converted/pruning_0.3/metadata.json
# Quantized model(0.3) convert task completed
# 2025-02-13 04:49:35.071 | INFO     | netspresso.np_qai.converter:update_convert_task:58 - ✅ SUCCESS
# pruning_0.5 (1).tflite: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2.47M/2.47M [00:00<00:00, 4.23MB/s]
# Downloaded model to /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/converted/pruning_0.5 (1)/pruning_0.5 (1).tflite
# 2025-02-13 04:49:36.801 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/converted/pruning_0.5 (1)/metadata.json
# Quantized model(0.5) convert task completed
# All tasks completed!

# %% [markdown]
# ## 3-4. Benchmark the performance across all models on-device using Qualcomm AI Hub

# %%
benchmarker = np_qai.benchmarker()

benchmark_tasks = {}
completed_benchmark_tasks = set()

for ratio in ratios:
    _benchmark_result = benchmarker.benchmark_model(
        input_model_path=convert_tasks[ratio].converted_model_path,
        target_device_name=Device("QCS6490 (Proxy)"),
        options=benchmark_options,
    )
    benchmark_tasks[ratio] = _benchmark_result
    print(f"Converted model({ratio}) benchmark task started")

while len(completed_benchmark_tasks) < len(ratios):
    for ratio in ratios:
        if ratio not in completed_benchmark_tasks:
            status = benchmarker.get_benchmark_task_status(benchmark_tasks[ratio].benchmark_task_info.benchmark_task_uuid)
            if status.finished:
                benchmark_tasks[ratio] = benchmarker.update_benchmark_task(benchmark_tasks[ratio])
                completed_benchmark_tasks.add(ratio)
                print(f"Converted model({ratio}) benchmark task completed")
            else:
                time.sleep(30)
                print(f"Converted model({ratio}) benchmark task is still running")

print("All tasks completed!")
# Out:
# 2025-02-13 04:49:36.829 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/converted/pruning_0.3/benchmark.json
# Uploading pruning_0.3.tflite
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4.56M/4.56M [00:01<00:00, 4.27MB/s]
# 2025-02-13 04:49:39.734 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/converted/pruning_0.3/benchmark.json
# 2025-02-13 04:49:39.738 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/converted/pruning_0.5 (1)/benchmark.json
# Scheduled profile job (jpvqr01kg) successfully. To see the status and results:
#     https://app.aihub.qualcomm.com/jobs/jpvqr01kg/
#
# Converted model(0.3) benchmark task started
# Uploading pruning_0.5 (1).tflite
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2.47M/2.47M [00:01<00:00, 2.34MB/s]
# 2025-02-13 04:49:42.369 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/converted/pruning_0.5 (1)/benchmark.json
# 2025-02-13 04:49:42.373 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/converted/pruning_0.7 (1)/benchmark.json
# Scheduled profile job (jgjd2z0vg) successfully. To see the status and results:
#     https://app.aihub.qualcomm.com/jobs/jgjd2z0vg/
#
# Converted model(0.5) benchmark task started
# Uploading pruning_0.7 (1).tflite
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1.00M/1.00M [00:01<00:00, 769kB/s]
# 2025-02-13 04:49:45.214 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/converted/pruning_0.7 (1)/benchmark.json
# Scheduled profile job (jpeowerog) successfully. To see the status and results:
#     https://app.aihub.qualcomm.com/jobs/jpeowerog/
#
# Converted model(0.7) benchmark task started
# Converted model(0.3) benchmark task is still running
# Converted model(0.5) benchmark task is still running
# Converted model(0.7) benchmark task is still running
# Converted model(0.3) benchmark task is still running
# Converted model(0.5) benchmark task is still running
# Converted model(0.7) benchmark task is still running
# 2025-02-13 04:52:50.744 | INFO     | netspresso.np_qai.benchmarker:update_benchmark_task:86 - ✅ SUCCESS
# 2025-02-13 04:52:51.388 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/converted/pruning_0.3/benchmark.json
# Converted model(0.3) benchmark task completed
# 2025-02-13 04:52:52.294 | INFO     | netspresso.np_qai.benchmarker:update_benchmark_task:86 - ✅ SUCCESS
# 2025-02-13 04:52:52.865 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/converted/pruning_0.5 (1)/benchmark.json
# Converted model(0.5) benchmark task completed
# Converted model(0.7) benchmark task is still running
# Converted model(0.7) benchmark task is still running
# Converted model(0.7) benchmark task is still running
# Converted model(0.7) benchmark task is still running
# Converted model(0.7) benchmark task is still running
# 2025-02-13 04:55:27.702 | INFO     | netspresso.np_qai.benchmarker:update_benchmark_task:86 - ✅ SUCCESS
# 2025-02-13 04:55:28.288 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/qai-hub-yolox-s (1)/converted/pruning_0.7 (1)/benchmark.json
# Converted model(0.7) benchmark task completed
# All tasks completed!

# %% [markdown]
# ## 3-5. Comparison of latency and FLOPs corresponding to the compression ratios

# %%
from netspresso.utils.plotter import Plotter

# %%
original_latency = benchmark_result.benchmark_result.latency
compressed_latency = {ratio : benchmark_tasks[ratio].benchmark_result.latency for ratio in ratios}
Plotter.compare_latency(original_latency=original_latency, latency_per_model=compressed_latency, target_latency=13)

# %%
original_flops = compressed_results[0.3].results.original_model.flops
compressed_flops = {ratio : compressed_results[ratio].results.compressed_model.flops for ratio in ratios}
Plotter.compare_flops(original_flops=original_flops, flops_per_model=compressed_flops)

# %% [markdown]
# # 4. Retrain the compressed model

# %% [markdown]
# ## 4-1. Train the compressed model

# %%
selected_pruning_ratio = 0.7 # The minimum pruning ratio required to achieve the target latency.

hparams_yaml = trained_result.hparams
compressed_model_path = compressed_results[selected_pruning_ratio].compressed_model_path

retrainer = netspresso.trainer(yaml_path=hparams_yaml)

retrainer.set_fx_model(fx_model_path=compressed_model_path)
retrainer.set_training_config(
    epochs=28,
    batch_size=64,
    optimizer=AdamW(lr=6e-3),
    scheduler=CosineAnnealingWarmRestartsWithCustomWarmUp(warmup_epochs=10),
)
project_name = "retraining_sample"
retraining_result = retrainer.train(gpus="0, 1", project_name=project_name)
# Out:
# 2025-02-13 06:48:36.751 | INFO     | netspresso.utils.file:create_unique_folder:90 - The folder has been created. Local Path: outputs/retraining_sample (5)
# 2025-02-13 06:48:36.754 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/retraining_sample (5)/metadata.json
# /opt/conda/lib/python3.10/site-packages/torch/distributed/launch.py:180: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   warnings.warn(
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# 2025-02-13 06:48:40.669 | INFO     | netspresso_trainer.trainer_common:train_common:50 - Task: detection | Model: yolox_s | Training with torch.fx model? False
# 2025-02-13 06:48:40.670 | INFO     | netspresso_trainer.trainer_common:train_common:51 - Result will be saved at outputs/retraining_sample (5)/version_0
# 2025-02-13 06:48:40.671 | INFO     | netspresso_trainer.dataloaders.builder:build_dataset:97 - ----------------------------------------
# 2025-02-13 06:48:40.671 | INFO     | netspresso_trainer.dataloaders.builder:build_dataset:98 - Loading data...
# 2025-02-13 06:48:40.709 | INFO     | netspresso_trainer.dataloaders.builder:loaded_dataset_check:72 - Summary | Dataset: <traffic_sign_config_example> (with local format)
# 2025-02-13 06:48:40.709 | INFO     | netspresso_trainer.dataloaders.builder:loaded_dataset_check:73 - Summary | Training dataset: 630 sample(s)
# 2025-02-13 06:48:40.709 | INFO     | netspresso_trainer.dataloaders.builder:loaded_dataset_check:75 - Summary | Validation dataset: 111 sample(s)
# 2025-02-13 06:48:41.975 | INFO     | netspresso_trainer.models.utils:load_from_checkpoint:216 - Pretrained model for yolox_s is loaded from: /root/.cache/netspresso_trainer/yolox_s/yolox_s_coco.safetensors
# 2025-02-13 06:48:41.988 | INFO     | netspresso_trainer.models.utils:load_from_checkpoint:220 - ----------------------------------------
# 2025-02-13 06:48:41.988 | INFO     | netspresso_trainer.models.utils:load_from_checkpoint:221 - Head weights are not loaded because model.checkpoint.load_head is set to False
#   0%|          | 0/4 [00:00<?, ?it/s]2025-02-13 06:48:44.201 | INFO     | netspresso_trainer.pipelines.train:train:128 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s][W reducer.cpp:1298] Warning: find_unused_parameters=True was specified in DDP constructor, but did not find any unused parameters in the forward pass. This flag results in an extra traversal of the autograd graph every iteration,  which can adversely affect performance. If your model indeed never has any unused parameters in the forward pass, consider turning this flag off. Note that this warning may be a false positive if your model has flow control causing later iterations to have unused parameters. (function operator())
# [W reducer.cpp:1298] Warning: find_unused_parameters=True was specified in DDP constructor, but did not find any unused parameters in the forward pass. This flag results in an extra traversal of the autograd graph every iteration,  which can adversely affect performance. If your model indeed never has any unused parameters in the forward pass, consider turning this flag off. Note that this warning may be a false positive if your model has flow control causing later iterations to have unused parameters. (function operator())
# 2025-02-13 06:48:55.133 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 1 / 28
# 2025-02-13 06:48:55.134 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0006090
# 2025-02-13 06:48:55.134 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 10.9294744
# 2025-02-13 06:48:55.134 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 41.1370668
# 2025-02-13 06:48:55.134 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.0247667729561328), ('map75', 0.005622018784551708), ('map50_95', 0.01043088493307721)]
# 2025-02-13 06:49:00.677 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - validation loss: 47.4143193
# 2025-02-13 06:49:00.677 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - validation metric: [('map50', 0.0), ('map75', 0.0), ('map50_95', 0.0)]
# 2025-02-13 06:49:00.694 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/retraining_sample (5)/version_0/training_summary.json
# 2025-02-13 06:49:02.064 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]2025-02-13 06:49:09.190 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 2 / 28
# 2025-02-13 06:49:09.192 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0012080
# 2025-02-13 06:49:09.192 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.1245379
# 2025-02-13 06:49:09.192 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 22.4689026
# 2025-02-13 06:49:09.192 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.05135617476428988), ('map75', 0.04426717521824032), ('map50_95', 0.03275481655793646)]
# 2025-02-13 06:49:09.195 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/retraining_sample (5)/version_0/training_summary.json
# 2025-02-13 06:49:09.196 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]2025-02-13 06:49:16.516 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 3 / 28
# 2025-02-13 06:49:16.517 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0018070
# 2025-02-13 06:49:16.517 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.3193233
# 2025-02-13 06:49:16.517 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 17.8252084
# 2025-02-13 06:49:16.517 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.029706800873805356), ('map75', 0.005185720694350115), ('map50_95', 0.01056193961363989)]
# 2025-02-13 06:49:16.520 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/retraining_sample (5)/version_0/training_summary.json
# 2025-02-13 06:49:16.520 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]2025-02-13 06:49:23.714 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 4 / 28
# 2025-02-13 06:49:23.716 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0024060
# 2025-02-13 06:49:23.717 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.1930015
# 2025-02-13 06:49:23.717 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 14.6742280
# 2025-02-13 06:49:23.718 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.122197435411317), ('map75', 0.004602263544205314), ('map50_95', 0.0327979651878048)]
# 2025-02-13 06:49:23.721 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/retraining_sample (5)/version_0/training_summary.json
# 2025-02-13 06:49:23.722 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]2025-02-13 06:49:31.076 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 5 / 28
# 2025-02-13 06:49:31.077 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0030050
# 2025-02-13 06:49:31.077 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.3523743
# 2025-02-13 06:49:31.077 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 12.4905355
# 2025-02-13 06:49:31.078 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.1119242552299069), ('map75', 0.005155185465749576), ('map50_95', 0.027745189203504002)]
# 2025-02-13 06:49:31.080 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/retraining_sample (5)/version_0/training_summary.json
# 2025-02-13 06:49:31.081 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]2025-02-13 06:49:37.997 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 6 / 28
# 2025-02-13 06:49:37.998 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0036040
# 2025-02-13 06:49:37.998 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 6.9155257
# 2025-02-13 06:49:37.999 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 11.6467490
# 2025-02-13 06:49:37.999 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.14593748064497059), ('map75', 0.005468339397492152), ('map50_95', 0.03166723264115415)]
# 2025-02-13 06:49:38.001 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/retraining_sample (5)/version_0/training_summary.json
# 2025-02-13 06:49:38.001 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]2025-02-13 06:49:45.184 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 7 / 28
# 2025-02-13 06:49:45.185 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0042030
# 2025-02-13 06:49:45.185 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.1815529
# 2025-02-13 06:49:45.185 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 11.3523571
# 2025-02-13 06:49:45.186 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.1546864352479797), ('map75', 0.005219404768006534), ('map50_95', 0.0373521761196259)]
# 2025-02-13 06:49:45.188 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/retraining_sample (5)/version_0/training_summary.json
# 2025-02-13 06:49:45.188 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]2025-02-13 06:49:52.080 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 8 / 28
# 2025-02-13 06:49:52.082 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0048020
# 2025-02-13 06:49:52.082 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 6.8911116
# 2025-02-13 06:49:52.082 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 9.7805588
# 2025-02-13 06:49:52.082 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.2317410563374892), ('map75', 0.013034197929524934), ('map50_95', 0.06396241109941228)]
# 2025-02-13 06:49:52.085 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/retraining_sample (5)/version_0/training_summary.json
# 2025-02-13 06:49:52.085 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]2025-02-13 06:49:59.001 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 9 / 28
# 2025-02-13 06:49:59.002 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0054010
# 2025-02-13 06:49:59.003 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 6.9149625
# 2025-02-13 06:49:59.003 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 9.1549187
# 2025-02-13 06:49:59.003 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.23209962409362994), ('map75', 0.017199733915344892), ('map50_95', 0.06653544409057902)]
# 2025-02-13 06:49:59.006 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/retraining_sample (5)/version_0/training_summary.json
# 2025-02-13 06:49:59.006 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]2025-02-13 06:50:05.924 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 10 / 28
# 2025-02-13 06:50:05.925 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0060000
# 2025-02-13 06:50:05.925 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 6.9166229
# 2025-02-13 06:50:05.925 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 7.8651938
# 2025-02-13 06:50:05.926 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.46707404475110004), ('map75', 0.08697376829776365), ('map50_95', 0.16707529967907658)]
# 2025-02-13 06:50:05.928 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/retraining_sample (5)/version_0/training_summary.json
# 2025-02-13 06:50:05.928 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
# 2025-02-13 06:50:15.258 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 11 / 28
# 2025-02-13 06:50:15.258 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0060000
# 2025-02-13 06:50:15.258 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 9.3283532
# 2025-02-13 06:50:15.259 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 7.0038933
# 2025-02-13 06:50:15.259 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.583890325085185), ('map75', 0.0763463892178635), ('map50_95', 0.21052503240567272)]
# 2025-02-13 06:50:20.819 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - validation loss: 432.7568316
# 2025-02-13 06:50:20.820 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - validation metric: [('map50', 0.0), ('map75', 0.0), ('map50_95', 0.0)]
# 2025-02-13 06:50:20.837 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/retraining_sample (5)/version_0/training_summary.json
# 2025-02-13 06:50:22.152 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 06:50:29.098 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 12 / 28
# 2025-02-13 06:50:29.099 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0059544
# 2025-02-13 06:50:29.100 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 6.9445202
# 2025-02-13 06:50:29.100 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 6.1934396
# 2025-02-13 06:50:29.100 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.6054787142258122), ('map75', 0.22766353512762988), ('map50_95', 0.29498947846011064)]
# 2025-02-13 06:50:29.102 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/retraining_sample (5)/version_0/training_summary.json
# 2025-02-13 06:50:29.102 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]2025-02-13 06:50:36.026 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 13 / 28
# 2025-02-13 06:50:36.027 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0058191
# 2025-02-13 06:50:36.028 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 6.9229043
# 2025-02-13 06:50:36.028 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 7.5808536
# 2025-02-13 06:50:36.028 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.35040918945478444), ('map75', 0.04313315155322612), ('map50_95', 0.12124953728133059)]
# 2025-02-13 06:50:36.030 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/retraining_sample (5)/version_0/training_summary.json
# 2025-02-13 06:50:36.030 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 06:50:43.336 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 14 / 28
# 2025-02-13 06:50:43.337 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0055981
# 2025-02-13 06:50:43.337 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.3049064
# 2025-02-13 06:50:43.338 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 5.9581099
# 2025-02-13 06:50:43.338 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.6569412342363825), ('map75', 0.15387599234289542), ('map50_95', 0.28036180550861933)]
# 2025-02-13 06:50:43.341 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/retraining_sample (5)/version_0/training_summary.json
# 2025-02-13 06:50:43.341 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 06:50:50.611 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 15 / 28
# 2025-02-13 06:50:50.612 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0052983
# 2025-02-13 06:50:50.613 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.2693272
# 2025-02-13 06:50:50.613 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 5.5921878
# 2025-02-13 06:50:50.613 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.7184506849138732), ('map75', 0.18732831395923896), ('map50_95', 0.3056147946963946)]
# 2025-02-13 06:50:50.616 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/retraining_sample (5)/version_0/training_summary.json
# 2025-02-13 06:50:50.616 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 06:50:57.880 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 16 / 28
# 2025-02-13 06:50:57.882 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0049285
# 2025-02-13 06:50:57.882 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.2630284
# 2025-02-13 06:50:57.882 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 4.6342127
# 2025-02-13 06:50:57.882 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.8426872173052546), ('map75', 0.35444045699081883), ('map50_95', 0.41824071795209566)]
# 2025-02-13 06:50:57.885 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/retraining_sample (5)/version_0/training_summary.json
# 2025-02-13 06:50:57.886 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 06:51:04.884 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 17 / 28
# 2025-02-13 06:51:04.885 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0045002
# 2025-02-13 06:51:04.885 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 6.9975014
# 2025-02-13 06:51:04.886 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 4.2883607
# 2025-02-13 06:51:04.886 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.8780818330683033), ('map75', 0.4806084323254199), ('map50_95', 0.47544005441063664)]
# 2025-02-13 06:51:04.888 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/retraining_sample (5)/version_0/training_summary.json
# 2025-02-13 06:51:04.889 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 06:51:11.875 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 18 / 28
# 2025-02-13 06:51:11.878 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0040264
# 2025-02-13 06:51:11.878 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 6.9851451
# 2025-02-13 06:51:11.878 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 4.2795657
# 2025-02-13 06:51:11.878 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.9170806904855435), ('map75', 0.3654585966546414), ('map50_95', 0.45327106020210317)]
# 2025-02-13 06:51:11.880 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/retraining_sample (5)/version_0/training_summary.json
# 2025-02-13 06:51:11.881 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 06:51:19.219 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 19 / 28
# 2025-02-13 06:51:19.220 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0035214
# 2025-02-13 06:51:19.220 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.3369904
# 2025-02-13 06:51:19.220 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 4.1057003
# 2025-02-13 06:51:19.221 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.9367749036498217), ('map75', 0.49246083521924544), ('map50_95', 0.500092807566548)]
# 2025-02-13 06:51:19.223 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/retraining_sample (5)/version_0/training_summary.json
# 2025-02-13 06:51:19.224 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 06:51:26.394 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 20 / 28
# 2025-02-13 06:51:26.396 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0030005
# 2025-02-13 06:51:26.396 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.1699827
# 2025-02-13 06:51:26.396 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 4.3293613
# 2025-02-13 06:51:26.396 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.9339837923538832), ('map75', 0.2953838393141698), ('map50_95', 0.43610501564012283)]
# 2025-02-13 06:51:26.399 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/retraining_sample (5)/version_0/training_summary.json
# 2025-02-13 06:51:26.399 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
# 2025-02-13 06:51:36.130 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 21 / 28
# 2025-02-13 06:51:36.130 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0024796
# 2025-02-13 06:51:36.131 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 9.7293601
# 2025-02-13 06:51:36.131 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 3.7535456
# 2025-02-13 06:51:36.131 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.956321697238356), ('map75', 0.5719196867611305), ('map50_95', 0.5487629824404007)]
# 2025-02-13 06:51:41.583 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - validation loss: 10.2657227
# 2025-02-13 06:51:41.584 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - validation metric: [('map50', 0.21462906425719372), ('map75', 0.033575238901412605), ('map50_95', 0.0784858557666012)]
# 2025-02-13 06:51:41.614 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/retraining_sample (5)/version_0/training_summary.json
# 2025-02-13 06:51:42.902 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 06:51:50.041 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 22 / 28
# 2025-02-13 06:51:50.044 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0019746
# 2025-02-13 06:51:50.044 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.1379063
# 2025-02-13 06:51:50.044 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 3.5979595
# 2025-02-13 06:51:50.044 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.9643660424269618), ('map75', 0.6069755844846989), ('map50_95', 0.5749586586014813)]
# 2025-02-13 06:51:50.047 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/retraining_sample (5)/version_0/training_summary.json
# 2025-02-13 06:51:50.047 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 06:51:57.291 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 23 / 28
# 2025-02-13 06:51:57.294 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0015008
# 2025-02-13 06:51:57.294 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.2436032
# 2025-02-13 06:51:57.294 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 3.0761268
# 2025-02-13 06:51:57.294 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.9683334962973104), ('map75', 0.8381313749767165), ('map50_95', 0.6589797749130668)]
# 2025-02-13 06:51:57.297 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/retraining_sample (5)/version_0/training_summary.json
# 2025-02-13 06:51:57.297 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 06:52:04.486 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 24 / 28
# 2025-02-13 06:52:04.487 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0010725
# 2025-02-13 06:52:04.488 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.1880066
# 2025-02-13 06:52:04.488 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 2.7168960
# 2025-02-13 06:52:04.488 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.9689144382579531), ('map75', 0.8904342496106986), ('map50_95', 0.7195805102505684)]
# 2025-02-13 06:52:04.491 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/retraining_sample (5)/version_0/training_summary.json
# 2025-02-13 06:52:04.492 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 06:52:11.591 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 25 / 28
# 2025-02-13 06:52:11.592 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0007027
# 2025-02-13 06:52:11.592 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.0983479
# 2025-02-13 06:52:11.593 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 2.5293105
# 2025-02-13 06:52:11.593 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.9711994932799272), ('map75', 0.9073753343332477), ('map50_95', 0.753986552975553)]
# 2025-02-13 06:52:11.596 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/retraining_sample (5)/version_0/training_summary.json
# 2025-02-13 06:52:11.596 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 06:52:18.833 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 26 / 28
# 2025-02-13 06:52:18.834 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0004029
# 2025-02-13 06:52:18.834 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.2358727
# 2025-02-13 06:52:18.835 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 2.4289787
# 2025-02-13 06:52:18.835 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.971433118487823), ('map75', 0.9202617004417251), ('map50_95', 0.7642021611723651)]
# 2025-02-13 06:52:18.838 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/retraining_sample (5)/version_0/training_summary.json
# 2025-02-13 06:52:18.838 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
#   0%|          | 0/4 [00:00<?, ?it/s]        2025-02-13 06:52:26.122 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 27 / 28
# 2025-02-13 06:52:26.123 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0001819
# 2025-02-13 06:52:26.123 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 7.2826567
# 2025-02-13 06:52:26.124 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 2.3476203
# 2025-02-13 06:52:26.124 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.9715907530338811), ('map75', 0.9357684523074561), ('map50_95', 0.774145599951465)]
# 2025-02-13 06:52:26.127 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/retraining_sample (5)/version_0/training_summary.json
# 2025-02-13 06:52:26.127 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
# 2025-02-13 06:52:35.367 | INFO     | netspresso_trainer.loggers.stdout:__call__:42 - Epoch: 28 / 28
# 2025-02-13 06:52:35.367 | INFO     | netspresso_trainer.loggers.stdout:__call__:45 - learning rate: 0.0000466
# 2025-02-13 06:52:35.368 | INFO     | netspresso_trainer.loggers.stdout:__call__:47 - elapsed_time: 9.2386239
# 2025-02-13 06:52:35.368 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - training loss: 2.2924665
# 2025-02-13 06:52:35.368 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - training metric: [('map50', 0.9718755530796918), ('map75', 0.9293222228489106), ('map50_95', 0.788986776106369)]
# 2025-02-13 06:52:41.036 | INFO     | netspresso_trainer.loggers.stdout:__call__:50 - validation loss: 4.1567916
# 2025-02-13 06:52:41.036 | INFO     | netspresso_trainer.loggers.stdout:__call__:52 - validation metric: [('map50', 0.8018368004880039), ('map75', 0.6439751455900369), ('map50_95', 0.5345245378248696)]
# 2025-02-13 06:52:41.067 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/retraining_sample (5)/version_0/training_summary.json
# 2025-02-13 06:52:42.369 | INFO     | netspresso_trainer.pipelines.train:train:160 - ----------------------------------------
# 2025-02-13 06:52:42.370 | INFO     | netspresso_trainer.pipelines.train:train:166 - Total time: 238.17 s
# 2025-02-13 06:52:42.577 | INFO     | netspresso_trainer.pipelines.train:save_best:295 - Best model saved at outputs/retraining_sample (5)/version_0/detection_yolox_s_best.safetensors
# /opt/conda/lib/python3.10/site-packages/torch/onnx/_internal/jit_utils.py:258: UserWarning: The shape inference of prim::Constant type is missing, so it may result in wrong shape inference for the exported graph. Please consider adding it in symbolic function. (Triggered internally at ../torch/csrc/jit/passes/onnx/shape_type_inference.cpp:1884.)
#   _C._jit_pass_onnx_node_shape_type_inference(node, params_dict, opset_version)
# /opt/conda/lib/python3.10/site-packages/torch/onnx/utils.py:687: UserWarning: The shape inference of prim::Constant type is missing, so it may result in wrong shape inference for the exported graph. Please consider adding it in symbolic function. (Triggered internally at ../torch/csrc/jit/passes/onnx/shape_type_inference.cpp:1884.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# /opt/conda/lib/python3.10/site-packages/torch/onnx/utils.py:1178: UserWarning: The shape inference of prim::Constant type is missing, so it may result in wrong shape inference for the exported graph. Please consider adding it in symbolic function. (Triggered internally at ../torch/csrc/jit/passes/onnx/shape_type_inference.cpp:1884.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# 2025-02-13 06:52:44.096 | INFO     | netspresso_trainer.pipelines.train:save_best:299 - ONNX model converting and saved at outputs/retraining_sample (5)/version_0/detection_yolox_s_best.onnx
# 2025-02-13 06:52:44.254 | INFO     | netspresso_trainer.pipelines.train:save_best:302 - PyTorch FX model tracing and saved at outputs/retraining_sample (5)/version_0/detection_yolox_s_best.pt
# 2025-02-13 06:52:44.567 | INFO     | netspresso_trainer.pipelines.train:save_summary:322 - [Model stats] | Sample input: (1, 3, 512, 512) | Params: 8.94M | FLOPs: 17.05G
# 2025-02-13 06:52:44.570 | INFO     | netspresso_trainer.pipelines.train:save_summary:335 - Model training summary saved at outputs/retraining_sample (5)/version_0/training_summary.json
# 2025-02-13 06:52:48.665 | INFO     | netspresso.clients.launcher.v2.converter:read_framework_options:175 - Request Convert options
# 2025-02-13 06:52:48.846 | INFO     | netspresso.clients.launcher.v2.converter:read_framework_options:180 - Request Convert Task Options by model_framework: ResponseConvertFrameworkOptionItems(data=[ModelOption(framework='tensorrt', display_framework='TensorRT', devices=[DeviceInfo(device_name='AWS-T4', display_device_name='NVIDIA AWS-T4', display_brand_name='NVIDIA', software_versions=[], data_types=['FP16'], hardware_types=[]), DeviceInfo(device_name='Jetson-AGX-Orin', display_device_name='NVIDIA Jetson AGX Orin', display_brand_name='NVIDIA', software_versions=[SoftwareVersionInfo(software_version='5.0.1-b118', display_software_version='Jetpack 5.0.1')], data_types=['FP16'], hardware_types=[]), DeviceInfo(device_name='Jetson-Nano', display_device_name='NVIDIA Jetson Nano', display_brand_name='NVIDIA', software_versions=[SoftwareVersionInfo(software_version='4.4.1-b50', display_software_version='Jetpack 4.4.1'), SoftwareVersionInfo(software_version='4.6-b199', display_software_version='Jetpack 4.6')], data_types=['FP16'], hardware_types=[]), DeviceInfo(device_name='Jetson-Nx', display_device_name='NVIDIA Jetson Xavier NX', display_brand_name='NVIDIA', software_versions=[SoftwareVersionInfo(software_version='4.6-b199', display_software_version='Jetpack 4.6'), SoftwareVersionInfo(software_version='5.0.2-b231', display_software_version='Jetpack 5.0.2')], data_types=['FP16'], hardware_types=[]), DeviceInfo(device_name='Jetson-Orin-Nano', display_device_name='NVIDIA Jetson Orin Nano', display_brand_name='NVIDIA', software_versions=[SoftwareVersionInfo(software_version='6.0-b52', display_software_version='Jetpack 6.0')], data_types=['FP16'], hardware_types=[]), DeviceInfo(device_name='Jetson-Tx2', display_device_name='NVIDIA Jetson Tx2', display_brand_name='NVIDIA', software_versions=[SoftwareVersionInfo(software_version='4.6-b199', display_software_version='Jetpack 4.6')], data_types=['FP16'], hardware_types=[]), DeviceInfo(device_name='Jetson-Xavier', display_device_name='NVIDIA Jetson AGX Xavier', display_brand_name='NVIDIA', software_versions=[SoftwareVersionInfo(software_version='4.6-b199', display_software_version='Jetpack 4.6')], data_types=['FP16'], hardware_types=[])]), ModelOption(framework='tensorflow_lite', display_framework='Tensorflow Lite', devices=[DeviceInfo(device_name='Arm Virtual Hardware Ethos-U Series', display_device_name='Arm Virtual Hardware Corstone-300 (Ethos-U55/U65)', display_brand_name='Arm', software_versions=[], data_types=['INT8'], hardware_types=[]), DeviceInfo(device_name='Ensemble-E7-DevKit-Gen2', display_device_name='Alif Ensemble DevKit-E7 Gen2 (Arm Cortex-M55+Ethos-U55)', display_brand_name='Arm', software_versions=[], data_types=['INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi-Zero2W', display_device_name='RaspberryPi Zero2W', display_brand_name='RaspberryPi', software_versions=[], data_types=['FP16', 'INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi-ZeroW', display_device_name='RaspberryPi ZeroW', display_brand_name='RaspberryPi', software_versions=[], data_types=['FP16', 'INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi2B', display_device_name='Raspberry Pi 2B', display_brand_name='RaspberryPi', software_versions=[], data_types=['FP16', 'INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi3B', display_device_name='Raspberry Pi 3B', display_brand_name='RaspberryPi', software_versions=[], data_types=['FP16', 'INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi3BPlus', display_device_name='Raspberry Pi 3B+', display_brand_name='RaspberryPi', software_versions=[], data_types=['FP16', 'INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi4B', display_device_name='Raspberry Pi 4B', display_brand_name='RaspberryPi', software_versions=[], data_types=['FP16', 'INT8'], hardware_types=[]), DeviceInfo(device_name='RaspberryPi5', display_device_name='RaspberryPi 5 (Arm Cortex-A76)', display_brand_name='RaspberryPi', software_ ...
# 2025-02-13 06:52:48.850 | INFO     | netspresso.trainer.trainer:train:626 - Removed /tmp/temp_np_trainer_configs_1l7h3v1q folder.
# 2025-02-13 06:52:48.853 | INFO     | netspresso.trainer.trainer:train:629 - Files in outputs/retraining_sample (5)/version_0 were moved to outputs/retraining_sample (5).
# 2025-02-13 06:52:48.910 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/retraining_sample (5)/metadata.json

# %% [markdown]
# ## 4-2. Comparison of performance metric between original model and compressed model

# %%
Plotter.compare_metric(trained_result, retraining_result)

# %%
Plotter.compare_profile_result(compressed_results[selected_pruning_ratio])

# %% [markdown]
# # 5. Inference the retrained model

# %% [markdown]
# ## 5-1. Quantize the retrained model using Qualcomm AI Hub

# %%
quantized_result = quantizer.quantize_model(
    input_model_path=retraining_result.best_onnx_model_path,
    output_dir=f"{retraining_result.output_dir}/quantized/trained_model_w8a8",
    calibration_data=calibration_data,
    weights_dtype=QuantizePrecision.INT8,
    activations_dtype=QuantizePrecision.INT8,
    job_name="detection_yolox_s_w8a8",
)
print("Quantization task started")

# Monitor task status
while True:
    status = quantizer.get_quantize_task_status(quantized_result.quantize_info.quantize_task_uuid)
    if status.finished:
        quantized_result = quantizer.update_quantize_task(quantized_result)
        print("Quantization task completed")
        break
    else:
        time.sleep(30)
        print("Quantization task is still running")
# Out:
# 2025-02-13 06:54:08.415 | INFO     | netspresso.utils.file:create_unique_folder:82 - The folder has been created. Local Path: /root/projects/qc/v1.14.0/outputs/retraining_sample (5)/quantized/trained_model_w8a8
# 2025-02-13 06:54:08.418 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/retraining_sample (5)/quantized/trained_model_w8a8/metadata.json
# Uploading detection_yolox_s_best.onnx
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 34.1M/34.1M [00:03<00:00, 10.2MB/s]
# Uploading dataset: 45.6MB [00:05, 9.48MB/s]                                                                                                                                                                       7.45MB/s]
# 2025-02-13 06:54:24.740 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/retraining_sample (5)/quantized/trained_model_w8a8/metadata.json
# Scheduled quantize job (jgkvq70vp) successfully. To see the status and results:
#     https://app.aihub.qualcomm.com/jobs/jgkvq70vp/
#
# Quantization task started
# Quantization task is still running
# Quantization task is still running
# Quantization task is still running
# Quantization task is still running
# Quantization task is still running
# 2025-02-13 06:56:59.389 | INFO     | netspresso.np_qai.quantizer:update_quantize_task:51 - ✅ SUCCESS
# trained_model_w8a8.onnx: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 34.4M/34.4M [00:01<00:00, 23.8MB/s]
# Downloaded model to /root/projects/qc/v1.14.0/outputs/retraining_sample (5)/quantized/trained_model_w8a8/trained_model_w8a8.onnx
# 2025-02-13 06:57:01.933 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/retraining_sample (5)/quantized/trained_model_w8a8/metadata.json
# Quantization task completed

# %% [markdown]
# ## 5-2. Compile and Optimize retrained model using Qualcomm AI Hub

# %%
converted_result = converter.convert_model(
    input_model_path=quantized_result.quantized_model_path,
    output_dir=f"{retraining_result.output_dir}/converted/quantized_model_tflite",
    target_device_name=Device("QCS6490 (Proxy)"),
    options=convert_options,
    input_shapes=dict(image=(1, 3, IMG_SIZE, IMG_SIZE)),
    job_name=f"detection_yolox_s_tflite",
)

print("Conversion task started")

# Monitor task status
while True:
    status = converter.get_convert_task_status(converted_result.convert_task_info.convert_task_uuid)
    if status.finished:
        converted_result = converter.update_convert_task(converted_result)
        print("Conversion task completed")
        break
    else:
        time.sleep(30)
        print("Conversion task is still running")
# Out:
# 2025-02-13 06:57:01.954 | INFO     | netspresso.utils.file:create_unique_folder:82 - The folder has been created. Local Path: /root/projects/qc/v1.14.0/outputs/retraining_sample (5)/converted/quantized_model_tflite
# 2025-02-13 06:57:01.958 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/retraining_sample (5)/converted/quantized_model_tflite/metadata.json
# Uploading trained_model_w8a8.onnx
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 34.4M/34.4M [00:05<00:00, 6.47MB/s]
# 2025-02-13 06:57:09.880 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/retraining_sample (5)/converted/quantized_model_tflite/metadata.json
# Scheduled compile job (jgz2joy4g) successfully. To see the status and results:
#     https://app.aihub.qualcomm.com/jobs/jgz2joy4g/
#
# Conversion task started
# Conversion task is still running
# Conversion task is still running
# 2025-02-13 06:58:11.962 | INFO     | netspresso.np_qai.converter:update_convert_task:58 - ✅ SUCCESS
# quantized_model_tflite.tflite: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8.89M/8.89M [00:00<00:00, 10.4MB/s]
# Downloaded model to /root/projects/qc/v1.14.0/outputs/retraining_sample (5)/converted/quantized_model_tflite/quantized_model_tflite.tflite
# 2025-02-13 06:58:14.367 | INFO     | netspresso.utils.metadata.handler:save_json:65 - JSON file saved at /root/projects/qc/v1.14.0/outputs/retraining_sample (5)/converted/quantized_model_tflite/metadata.json
# Conversion task completed

# %% [markdown]
# ## 5-3. Define preprocessor & postprocessor

# %%
import cv2
from glob import glob

from netspresso.inferencer.preprocessors.base import Preprocessor
from netspresso.inferencer.postprocessors.detection import DetectionPostprocessor as Postprocessor
from netspresso.inferencer.visualizers.detection import DetectionVisualizer as Visualizer

# %%
preprocess_list = [
    {
        "name": "resize",
        "size": IMG_SIZE,
        "interpolation": "bilinear",
        "max_size": None,
        "resize_criteria": "long",
    },
    {
        "name": "pad",
        "size": IMG_SIZE,
        "fill": 114,
    }
]

preprocessor = Preprocessor(preprocess_list)
postprocessor = Postprocessor(score_thresh=0.4, nms_thresh=0.65)
visualizer = Visualizer(class_map=["prohibitory", "danger", "mandatory", "other"], brightness_factor=1.5)

# %% [markdown]
# ## 5-4. Preprocess

# %%
colored_img = cv2.imread("./traffic-sign/images/valid/00644.jpg")
img = cv2.cvtColor(colored_img, cv2.COLOR_BGR2RGB)
img_draw = img.copy()
img = preprocessor(img)
transposed_img = img.transpose(0, 3, 1, 2)

# %% [markdown]
# ## 5-5. Run inference on-device using Qualcomm AI Hub

# %%
from netspresso.np_qai import Device
from netspresso.np_qai.options import CompileOptions, Runtime, ComputeUnit, ProfileOptions, TfliteOptions

inference_job = benchmarker.inference_model(
    input_model_path=converted_result.converted_model_path,
    target_device_name=Device(name="QCS6490 (Proxy)"),
    inputs=dict(image=[transposed_img]),
)

while True:
    status = benchmarker.get_inference_task_status(inference_job.job_id)
    if status.finished:
        print("Inference task completed")
        break
    else:
        time.sleep(30)
        print("Inference task is still running")
# Out:
# Uploading quantized_model_tflite.tflite
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8.89M/8.89M [00:01<00:00, 4.90MB/s]
# Uploading dataset: 595kB [00:01, 513kB/s]                                                                                                                                                                         <?, ?B/s]
# Scheduled inference job (jgdnqe465) successfully. To see the status and results:
#     https://app.aihub.qualcomm.com/jobs/jgdnqe465/
#
# Inference task is still running
# Inference task is still running
# Inference task is still running
# Inference task is still running
# Inference task is still running
# Inference task is still running
# Inference task completed

# %% [markdown]
# ## 5-6. Download on-device output for QCS6490

# %%
output_data = inference_job.download_output_data()
output = [value[0] for key, value in output_data.items()]
# Out:
# tmpkcdge_52.h5: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 51.6k/51.6k [00:00<00:00, 14.4MB/s]

# %% [markdown]
# ## 5-7. Postprocess

# %%
model_input_shape = img.shape[1:3]
pred = postprocessor({'pred': output}, model_input_shape)[0]

# %% [markdown]
# ## 5-8. Draw result image

# %%
img_draw = visualizer.draw(img_draw, pred, model_input_shape, text_scale=1, text_thickness=3, bbox_thickness=5)
visualizer.visualize_by_plt(img_draw)
